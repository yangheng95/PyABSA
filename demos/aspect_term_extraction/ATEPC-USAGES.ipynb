# %% [markdown]
# # Aspect term extraction and sentiment classification via [PyABSA](https://github.com/yangheng95/PyABSA)
# More usages see [here](https://github.com/yangheng95/PyABSA/tree/release/demos/aspect_term_extraction)

# %%
# !pip install pyabsa
# Out:
# Collecting pyabsa
#   Downloading pyabsa-1.10.1-py3-none-any.whl (207 kB)
#      |████████████████████████████████| 207 kB 4.3 MB/s
# Collecting pytorch-warmup
#   Downloading pytorch-warmup-0.1.0.tar.gz (314 kB)
#      |████████████████████████████████| 314 kB 50.7 MB/s
# Collecting findfile>=1.7.3
#   Downloading findfile-1.7.7-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from pyabsa) (1.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pyabsa) (4.64.0)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 56.7 MB/s
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 2.0 MB/s
# Collecting autocuda>=0.9
#   Downloading autocuda-0.11-py3-none-any.whl (4.8 kB)
# Collecting gitpython
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 52.3 MB/s
# Requirement already satisfied: torch<1.11.0,>1.0.0 in /usr/local/lib/python3.7/dist-packages (from pyabsa) (1.10.0+cu111)
# Collecting update-checker
#   Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from pyabsa) (2.6.3)
# Collecting metric-visualizer>=0.4.16
#   Downloading metric_visualizer-0.4.17-py3-none-any.whl (10 kB)
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (from pyabsa) (2.2.4)
# Requirement already satisfied: gdown>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from pyabsa) (4.4.0)
# Collecting transformers>4.5
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 31.8 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from pyabsa) (4.1.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown>=4.4.0->pyabsa) (4.6.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from gdown>=4.4.0->pyabsa) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown>=4.4.0->pyabsa) (3.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown>=4.4.0->pyabsa) (1.15.0)
# Collecting tikzplotlib
#   Downloading tikzplotlib-0.10.1-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.7 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from metric-visualizer>=0.4.16->pyabsa) (1.4.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from metric-visualizer>=0.4.16->pyabsa) (0.8.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from metric-visualizer>=0.4.16->pyabsa) (3.2.2)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 39.4 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers>4.5->pyabsa) (1.21.5)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 6.8 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>4.5->pyabsa) (2019.12.20)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 19.1 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers>4.5->pyabsa) (21.3)
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 75.1 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers>4.5->pyabsa) (4.11.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers>4.5->pyabsa) (3.0.8)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.8 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers>4.5->pyabsa) (3.8.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->metric-visualizer>=0.4.16->pyabsa) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->metric-visualizer>=0.4.16->pyabsa) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->metric-visualizer>=0.4.16->pyabsa) (2.8.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown>=4.4.0->pyabsa) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown>=4.4.0->pyabsa) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown>=4.4.0->pyabsa) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown>=4.4.0->pyabsa) (2021.10.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown>=4.4.0->pyabsa) (1.7.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>4.5->pyabsa) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>4.5->pyabsa) (1.1.0)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval->pyabsa) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->pyabsa) (3.1.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy->pyabsa) (1.0.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy->pyabsa) (0.9.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy->pyabsa) (1.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy->pyabsa) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy->pyabsa) (2.0.6)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy->pyabsa) (7.4.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy->pyabsa) (0.4.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy->pyabsa) (1.0.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy->pyabsa) (57.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy->pyabsa) (3.0.6)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from tikzplotlib->metric-visualizer>=0.4.16->pyabsa) (7.1.2)
# Collecting webcolors
#   Downloading webcolors-1.11.1-py3-none-any.whl (9.9 kB)
# Building wheels for collected packages: pytorch-warmup, seqeval
#   Building wheel for pytorch-warmup (setup.py) ... done
#   Created wheel for pytorch-warmup: filename=pytorch_warmup-0.1.0-py3-none-any.whl size=5802 sha256=ad781ea49e912aba626ff7e18f27c197cf8b175c67e028913c6fd8e54df80df5
#   Stored in directory: /root/.cache/pip/wheels/c7/5d/24/9475e442daa1e9332c122c79fb5131b9e4e91946009365902e
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=7a4e9e5722b03b9ebb4b8faf0cda5a4279fde711dd2b155357f8f34d0d4a4ac5
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built pytorch-warmup seqeval
# Installing collected packages: webcolors, smmap, pyyaml, tokenizers, tikzplotlib, sacremoses, huggingface-hub, gitdb, findfile, update-checker, transformers, seqeval, sentencepiece, pytorch-warmup, metric-visualizer, gitpython, autocuda, pyabsa
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed autocuda-0.11 findfile-1.7.7 gitdb-4.0.9 gitpython-3.1.27 huggingface-hub-0.5.1 metric-visualizer-0.4.17 pyabsa-1.10.1 pytorch-warmup-0.1.0 pyyaml-6.0 sacremoses-0.0.49 sentencepiece-0.1.96 seqeval-1.2.2 smmap-5.0.0 tikzplotlib-0.10.1 tokenizers-0.12.1 transformers-4.18.0 update-checker-0.18.0 webcolors-1.11.1

# %% [markdown]
# ## Find Available Checkpoints For **Current Version**

# %%
from pyabsa import available_checkpoints
checkpoint_map = available_checkpoints()
# Out:
# This script could only be used to manage NVIDIA GPUs,but no GPU found in your device
# Remote ABSADataset version: 2022.03.22 Local ABSADatasets version: N.A.
# Unknown local version for ABSADatasets, please check the latest version of ABSADatasets at https://github.com/yangheng95/ABSADatasets
# Downloading...
# From: https://drive.google.com/uc?id=1CBVGPA3xdQqdkFFwzO5T2Q4reFtzFIJZ
# To: /content/checkpoints.json
# 100%|██████████| 6.39k/6.39k [00:00<00:00, 1.79MB/s]
# ********** Available APC model checkpoints for Version:1.10.1 (this version) **********
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/1B0RHazOCm2eOWLWExQkeapHr9d3OiZl7/view?usp=sharing
# Training Model: FAST-LCF-MDeBERTa
# Training Dataset: Chinese
# Description: Trained on RTX3090
# Available Version: 1.8.2+
# Checkpoint File: fast_lcf_bert_Chinese_acc_97.11_f1_96.54.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/15ls1hcGvk27UnfMsXZtk780h7tTBbNws/view?usp=sharing
# Training Model: FAST-LCF-Deberta
# Training Dataset: Multilingual
# Description: Trained on RTX3090
# Available Version: 1.8.2+
# Checkpoint File: fast_lcf_bert_Multilingual_acc_94.72_f1_90.07.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id:
# Description: You can help us by sharing checkpoints (e.g. models trained on you own datasets) with community.
# Checkpoint File: PLEASE NOTE THAT THIS IS NOT A REAL CHECKPOINT!
# Available Version:
# ----------------------------------------------------------------------------------------------------
# ********** Available ATEPC model checkpoints for Version:1.10.1 (this version) **********
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/1HjJm80Ed5LLVYCLldRl_r9a_VJ_E9AcQ/view?usp=sharing
# Training Model: FAST-LCF-ATEPC
# Training Dataset: English
# Description: Trained on RTX3090
# Available Version: 1.8.4+
# Checkpoint File: fast_lcf_atepc_English_cdw_apcacc_80.16_apcf1_78.34_atef1_75.39.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/1GvfHAWVJeEKXoy2-bPtourWEniCfwwv0/view?usp=sharing
# Training Model: FAST-LCF-ATEPC
# Training Dataset: English
# Description: Trained on RTX3090
# Available Version: 1.8.4+
# Checkpoint File: fast_lcf_atepc_English_cdw_apcacc_82.93_apcf1_80.7_atef1_78.77.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/1X9-IulQuk1MBNfoHoi_RIW8e3qUgeyH2/view?usp=sharing
# Training Model: FAST-LCFS-ATEPC
# Training Dataset: English
# Description: Trained on RTX3090, this checkpoint use bert-spc in ATEPC training
# Available Version: 1.8.4+
# Checkpoint File: fast_lcfs_atepc_English_cdw_apcacc_85.03_apcf1_82.36_atef1_84.48.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/1SzzUkuMJLjfxGZmInqmBQi5U2ZxTeG2L/view?usp=sharing
# Training Model: FAST-LCF-DeBERTa
# Training Dataset: Chinese
# Description: Trained on RTX3090
# Available Version: 1.8.4+
# Checkpoint File: fast_lcf_atepc_Chinese_cdw_apcacc_96.69_apcf1_96.25_atef1_92.26.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/155itPM5hz037ytvqu6XuMArbxy3B2Vr8/view?usp=sharing
# Training Model: FAST-LCF-ATEPC
# Training Dataset: ABSADatasets.Multilingual
# Description: Trained on RTX3090
# Available Version: 1.8.4+
# Checkpoint File: fast_lcf_atepc_Multilingual_cdw_apcacc_79.61_apcf1_76.24_atef1_63.29.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/1LAC-AJfCf50r_7dtDzj73kn02Mr5g2ky/view?usp=sharing
# Training Model: FAST-LCF-ATEPC
# Training Dataset: ABSADatasets.Multilingual
# Description: Trained on RTX3090
# Available Version: 1.8.4+
# Checkpoint File: fast_lcf_atepc_Multilingual_cdw_apcacc_86.37_apcf1_82.94_atef1_84.78.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id:
# Description: You can help us by sharing checkpoints (e.g. models trained on you own datasets) with community.
# Checkpoint File: PLEASE NOTE THAT THIS IS NOT A REAL CHECKPOINT!
# Available Version:
# ----------------------------------------------------------------------------------------------------
# ********** Available TC model checkpoints for Version:1.10.1 (this version) **********
# ----------------------------------------------------------------------------------------------------
# id:
# Description: You can help us by sharing checkpoints (e.g. models trained on you own datasets) with community.
# Checkpoint File: PLEASE NOTE THAT THIS IS NOT A REAL CHECKPOINT!
# Available Version:
# ----------------------------------------------------------------------------------------------------
# There may be some checkpoints available for early versions of PyABSA, see ./checkpoints.json
# /usr/local/lib/python3.7/dist-packages/pyabsa/functional/checkpoint/checkpoint_manager.py:269: ResourceWarning: unclosed file <_io.TextIOWrapper name='./checkpoints.json' mode='r' encoding='UTF-8'>
#   checkpoint_map = json.load(open('./checkpoints.json', 'r'))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %% [markdown]
# # Init a aspect extractor from online checkpoint or local checkpoint

# %%
from pyabsa import ABSADatasetList, available_checkpoints
from pyabsa import ATEPCCheckpointManager

aspect_extractor = ATEPCCheckpointManager.get_aspect_extractor(checkpoint='english2',
                                   auto_device=True  # False means load model on CPU
                                   )
# Out:
# This script could only be used to manage NVIDIA GPUs,but no GPU found in your device
# Remote ABSADataset version: 2022.03.22 Local ABSADatasets version: N.A.
# Unknown local version for ABSADatasets, please check the latest version of ABSADatasets at https://github.com/yangheng95/ABSADatasets
# Downloading...
# From: https://drive.google.com/uc?id=1CBVGPA3xdQqdkFFwzO5T2Q4reFtzFIJZ
# To: /content/checkpoints.json
# 100%|██████████| 6.39k/6.39k [00:00<00:00, 3.05MB/s]
# /usr/local/lib/python3.7/dist-packages/pyabsa/functional/checkpoint/checkpoint_manager.py:269: ResourceWarning: unclosed file <_io.TextIOWrapper name='./checkpoints.json' mode='r' encoding='UTF-8'>
#   checkpoint_map = json.load(open('./checkpoints.json', 'r'))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# ********** Available ATEPC model checkpoints for Version:1.10.1 (this version) **********
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/1HjJm80Ed5LLVYCLldRl_r9a_VJ_E9AcQ/view?usp=sharing
# Training Model: FAST-LCF-ATEPC
# Training Dataset: English
# Description: Trained on RTX3090
# Available Version: 1.8.4+
# Checkpoint File: fast_lcf_atepc_English_cdw_apcacc_80.16_apcf1_78.34_atef1_75.39.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/1GvfHAWVJeEKXoy2-bPtourWEniCfwwv0/view?usp=sharing
# Training Model: FAST-LCF-ATEPC
# Training Dataset: English
# Description: Trained on RTX3090
# Available Version: 1.8.4+
# Checkpoint File: fast_lcf_atepc_English_cdw_apcacc_82.93_apcf1_80.7_atef1_78.77.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/1X9-IulQuk1MBNfoHoi_RIW8e3qUgeyH2/view?usp=sharing
# Training Model: FAST-LCFS-ATEPC
# Training Dataset: English
# Description: Trained on RTX3090, this checkpoint use bert-spc in ATEPC training
# Available Version: 1.8.4+
# Checkpoint File: fast_lcfs_atepc_English_cdw_apcacc_85.03_apcf1_82.36_atef1_84.48.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/1SzzUkuMJLjfxGZmInqmBQi5U2ZxTeG2L/view?usp=sharing
# Training Model: FAST-LCF-DeBERTa
# Training Dataset: Chinese
# Description: Trained on RTX3090
# Available Version: 1.8.4+
# Checkpoint File: fast_lcf_atepc_Chinese_cdw_apcacc_96.69_apcf1_96.25_atef1_92.26.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/155itPM5hz037ytvqu6XuMArbxy3B2Vr8/view?usp=sharing
# Training Model: FAST-LCF-ATEPC
# Training Dataset: ABSADatasets.Multilingual
# Description: Trained on RTX3090
# Available Version: 1.8.4+
# Checkpoint File: fast_lcf_atepc_Multilingual_cdw_apcacc_79.61_apcf1_76.24_atef1_63.29.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/1LAC-AJfCf50r_7dtDzj73kn02Mr5g2ky/view?usp=sharing
# Training Model: FAST-LCF-ATEPC
# Training Dataset: ABSADatasets.Multilingual
# Description: Trained on RTX3090
# Available Version: 1.8.4+
# Checkpoint File: fast_lcf_atepc_Multilingual_cdw_apcacc_86.37_apcf1_82.94_atef1_84.78.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id:
# Description: You can help us by sharing checkpoints (e.g. models trained on you own datasets) with community.
# Checkpoint File: PLEASE NOTE THAT THIS IS NOT A REAL CHECKPOINT!
# Available Version:
# ----------------------------------------------------------------------------------------------------
# There may be some checkpoints available for early versions of PyABSA, see ./checkpoints.json
# Downloading checkpoint:english2 from Google Drive...
# Notice: The pretrained model are used for testing, neither trained using fine-tuned hyper-parameters nor trained with enough steps, it is recommended to train the model on your own custom datasets
# Downloading...
# From: https://drive.google.com/uc?id=1GvfHAWVJeEKXoy2-bPtourWEniCfwwv0
# To: /content/checkpoints/ATEPC_ENGLISH2_CHECKPOINT/any_model.zip
# 100%|██████████| 649M/649M [00:11<00:00, 54.5MB/s]
# Find zipped checkpoint: ./checkpoints/ATEPC_ENGLISH2_CHECKPOINT/any_model.zip, unzipping...
# Done.
# Google Drive applies a restriction on public large file downloading, if you find the checkpoint downloaded is None or small, please download it via browser: 1GvfHAWVJeEKXoy2-bPtourWEniCfwwv0
# Load aspect extractor from ./checkpoints/ATEPC_ENGLISH2_CHECKPOINT
# config: ./checkpoints/ATEPC_ENGLISH2_CHECKPOINT/any_model/fast_lcf_atepc_English_cdw_apcacc_82.93_apcf1_80.7_atef1_78.77/fast_lcf_atepc.config
# state_dict: ./checkpoints/ATEPC_ENGLISH2_CHECKPOINT/any_model/fast_lcf_atepc_English_cdw_apcacc_82.93_apcf1_80.7_atef1_78.77/fast_lcf_atepc.state_dict
# model: None
# tokenizer: ./checkpoints/ATEPC_ENGLISH2_CHECKPOINT/any_model/fast_lcf_atepc_English_cdw_apcacc_82.93_apcf1_80.7_atef1_78.77/fast_lcf_atepc.tokenizer
# /usr/local/lib/python3.7/dist-packages/pyabsa/core/atepc/prediction/aspect_extractor.py:69: ResourceWarning: unclosed file <_io.BufferedReader name='./checkpoints/ATEPC_ENGLISH2_CHECKPOINT/any_model/fast_lcf_atepc_English_cdw_apcacc_82.93_apcf1_80.7_atef1_78.77/fast_lcf_atepc.config'>
#   self.opt = pickle.load(open(config_path, mode='rb'))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# Downloading:   0%|          | 0.00/785 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/701M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/368 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.35M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/18.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/156 [00:00<?, ?B/s]
# Config used in Training:
# ABSADatasetsVersion:2021.12.06	-->	Calling Count:0
# IOB_label_to_index:{'O': 1, 'B-ASP': 2, 'I-ASP': 3, '[CLS]': 4, '[SEP]': 5}	-->	Calling Count:0
# MV:<metric_visualizer.metric_visualizer.MetricVisualizer object at 0x7f6b85f3ff50>	-->	Calling Count:0
# PyABSAVersion:1.8.38a0	-->	Calling Count:0
# SRD:3	-->	Calling Count:74534
# TorchVersion:1.10.1+cuda11.3	-->	Calling Count:0
# TransformersVersion:4.17.0	-->	Calling Count:0
# auto_device:True	-->	Calling Count:63974
# batch_size:16	-->	Calling Count:5
# cache_dataset:True	-->	Calling Count:1
# dataset_file:{'train': ['integrated_datasets/atepc_datasets/SemEval/laptop14/Laptops_Train.xml.seg.atepc', 'integrated_datasets/atepc_datasets/SemEval/restaurant14/Restaurants_Train.xml.seg.atepc', 'integrated_datasets/atepc_datasets/SemEval/restaurant16/restaurant_train.raw.atepc', 'integrated_datasets/atepc_datasets/ACL_Twitter/acl-14-short-data/train.raw.atepc', 'integrated_datasets/atepc_datasets/MAMS/train.xml.dat.atepc', 'integrated_datasets/atepc_datasets/Television/Television_Train.xml.seg.atepc', 'integrated_datasets/atepc_datasets/TShirt/Menstshirt_Train.xml.seg.atepc', 'integrated_datasets/atepc_datasets/Yelp/yelp.train.txt.atepc'], 'test': ['integrated_datasets/atepc_datasets/SemEval/laptop14/Laptops_Test_Gold.xml.seg.atepc', 'integrated_datasets/atepc_datasets/SemEval/restaurant14/Restaurants_Test_Gold.xml.seg.atepc', 'integrated_datasets/atepc_datasets/SemEval/restaurant16/restaurant_test.raw.atepc', 'integrated_datasets/atepc_datasets/ACL_Twitter/acl-14-short-data/test.raw.atepc', 'integrated_datasets/atepc_datasets/MAMS/test.xml.dat.atepc', 'integrated_datasets/atepc_datasets/Television/Television_Test_Gold.xml.seg.atepc', 'integrated_datasets/atepc_datasets/TShirt/Menstshirt_Test_Gold.xml.seg.atepc', 'integrated_datasets/atepc_datasets/Yelp/yelp.test.txt.atepc'], 'valid': []}	-->	Calling Count:36154
# dataset_name:English	-->	Calling Count:21
# device:cuda:0	-->	Calling Count:450572
# device_name:NVIDIA GeForce RTX 3090	-->	Calling Count:0
# dropout:0.5	-->	Calling Count:2
# dynamic_truncate:True	-->	Calling Count:74534
# embed_dim:768	-->	Calling Count:0
# evaluate_begin:0	-->	Calling Count:38
# gradient_accumulation_steps:1	-->	Calling Count:3
# hidden_dim:768	-->	Calling Count:12
# index_to_IOB_label:{1: 'O', 2: 'B-ASP', 3: 'I-ASP', 4: '[CLS]', 5: '[SEP]'}	-->	Calling Count:0
# index_to_label:{0: 'Negative', 1: 'Neutral', 2: 'Positive'}	-->	Calling Count:2
# initializer:xavier_uniform_	-->	Calling Count:0
# l2reg:1e-08	-->	Calling Count:2
# label_list:['O', 'B-ASP', 'I-ASP', '[CLS]', '[SEP]']	-->	Calling Count:5412881
# label_to_index:{'Negative': 0, 'Neutral': 1, 'Positive': 2}	-->	Calling Count:0
# lcf:cdw	-->	Calling Count:100141
# learning_rate:1e-05	-->	Calling Count:1
# log_step:1954	-->	Calling Count:36151
# max_seq_len:80	-->	Calling Count:360993
# max_test_metrics:{'max_apc_test_acc': 82.93, 'max_apc_test_f1': 80.7, 'max_ate_test_f1': 78.97}	-->	Calling Count:289
# metrics_of_this_checkpoint:{'apc_acc': 82.93, 'apc_f1': 80.7, 'ate_f1': 78.77}	-->	Calling Count:111
# model:<class 'pyabsa.core.atepc.models.fast_lcf_atepc.FAST_LCF_ATEPC'>	-->	Calling Count:5
# model_name:fast_lcf_atepc	-->	Calling Count:37398
# model_path_to_save:checkpoints	-->	Calling Count:40
# num_epoch:20	-->	Calling Count:2
# num_labels:6	-->	Calling Count:6
# optimizer:adamw	-->	Calling Count:2
# patience:99999	-->	Calling Count:22
# polarities_dim:3	-->	Calling Count:39
# pretrained_bert:yangheng/deberta-v3-base-absa	-->	Calling Count:6
# save_mode:1	-->	Calling Count:37
# seed:52	-->	Calling Count:10
# sep_indices:2	-->	Calling Count:800666
# show_metric:False	-->	Calling Count:0
# spacy_model:en_core_web_sm	-->	Calling Count:3
# srd_alignment:True	-->	Calling Count:0
# use_bert_spc:False	-->	Calling Count:64011
# use_syntax_based_SRD:False	-->	Calling Count:37267
# window:lr	-->	Calling Count:0

# %% [markdown]
# # Aspect Term Extract & Sentiment Inference

# %%
# You can inference from a list of setences or a DatasetItem from PyABSA 
examples = ['But the staff was so perfect to us, but the service was bad .',
            ]
inference_source = examples
atepc_result = aspect_extractor.extract_aspect(inference_source=inference_source,  #
                          save_result=True,
                          print_result=True,  # print the result
                          pred_sentiment=True,  # Predict the sentiment of extracted aspect terms
                          )
# Out:
# /usr/local/lib/python3.7/dist-packages/catalogue.py:138: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for entry_point in AVAILABLE_ENTRY_POINTS.get(self.entry_point_namespace, []):
# /usr/local/lib/python3.7/dist-packages/transformers/models/deberta_v2/modeling_deberta_v2.py:538: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   bucket_pos = np.where(abs_pos <= mid, relative_pos, log_pos * sign).astype(np.int)
# /usr/local/lib/python3.7/dist-packages/pyabsa/core/atepc/prediction/aspect_extractor.py:351: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   lcf_cdm_vec = torch.tensor([f.lcf_cdm_vec for f in infer_features], dtype=torch.float32)
# The results of aspect term extraction have been saved in /content/atepc_inference.result.json
# {'sentence': 'but the staff was so perfect to us , but the service was bad .', 'IOB': ['O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O'], 'tokens': ['but', 'the', 'staff', 'was', 'so', 'perfect', 'to', 'us', ',', 'but', 'the', 'service', 'was', 'bad', '.'], 'aspect': ['staff', 'service'], 'position': [[3], [12]], 'sentiment': ['Positive', 'Negative']}
# /usr/local/lib/python3.7/dist-packages/pyabsa/core/atepc/prediction/aspect_extractor.py:221: ResourceWarning: unclosed file <_io.TextIOWrapper name='/content/atepc_inference.result.json' mode='w' encoding='UTF-8'>
#   json.dump(json.JSONEncoder().encode({'results': results}), open(save_path, 'w'), ensure_ascii=False)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %% [markdown]
# # Batch Inference

# %%
inference_source = ABSADatasetList.SemEval
atepc_result = aspect_extractor.extract_aspect(inference_source=inference_source,  #
                          save_result=True,
                          print_result=True,  # print the result
                          pred_sentiment=True,  # Predict the sentiment of extracted aspect terms
                          )
# Out:
# Loading Laptop14 dataset from:  https://github.com/yangheng95/ABSADatasets
# Clone ABSADatasets from https://github.com/yangheng95/ABSADatasets.git
# FindFile Warning: multiple targets ['integrated_datasets/apc_datasets/110.SemEval/113.laptop14', 'integrated_datasets/apc_datasets/110.SemEval/111.arts_laptop14'] found but return the shortest path
# loading: integrated_datasets/apc_datasets/110.SemEval/113.laptop14/Laptops_Test_Gold.xml.seg.inference
# Loading Restaurant14 dataset from:  https://github.com/yangheng95/ABSADatasets
# FindFile Warning: multiple targets ['integrated_datasets/apc_datasets/110.SemEval/112.arts_restaurant14', 'integrated_datasets/apc_datasets/110.SemEval/114.restaurant14'] found but return the shortest path
# loading: integrated_datasets/apc_datasets/110.SemEval/114.restaurant14/Restaurants_Test_Gold.xml.seg.inference
# Loading Restaurant16 dataset from:  https://github.com/yangheng95/ABSADatasets
# loading: integrated_datasets/apc_datasets/110.SemEval/116.restaurant16/restaurant_test.raw.inference
# /usr/local/lib/python3.7/dist-packages/catalogue.py:138: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for entry_point in AVAILABLE_ENTRY_POINTS.get(self.entry_point_namespace, []):
# /usr/local/lib/python3.7/dist-packages/transformers/models/deberta_v2/modeling_deberta_v2.py:538: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   bucket_pos = np.where(abs_pos <= mid, relative_pos, log_pos * sign).astype(np.int)
# The results of aspect term extraction have been saved in /content/atepc_inference.result.json
# {'sentence': 'serves really good sushi .', 'IOB': ['O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['serves', 'really', 'good', 'sushi', '.'], 'aspect': ['sushi'], 'position': [[4]], 'sentiment': ['Positive']}
# {'sentence': 'not the biggest portions but adequate .', 'IOB': ['O', 'O', 'O', 'B-ASP', 'O', 'O', 'O'], 'tokens': ['not', 'the', 'biggest', 'portions', 'but', 'adequate', '.'], 'aspect': ['portions'], 'position': [[4]], 'sentiment': ['Positive']}
# {'sentence': 'green tea creme brulee is a must !', 'IOB': ['B-ASP', 'I-ASP', 'I-ASP', 'I-ASP', 'O', 'O', 'O', 'O'], 'tokens': ['green', 'tea', 'creme', 'brulee', 'is', 'a', 'must', '!'], 'aspect': ['green tea creme brulee'], 'position': [[1, 2, 3, 4]], 'sentiment': ['Positive']}
# {'sentence': "– i ca n ' t say enough about this place .", 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['–', 'i', 'ca', 'n', "'", 't', 'say', 'enough', 'about', 'this', 'place', '.'], 'aspect': ['place'], 'position': [[11]], 'sentiment': ['Positive']}
# {'sentence': 'it has great sushi and even better service .', 'IOB': ['O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['it', 'has', 'great', 'sushi', 'and', 'even', 'better', 'service', '.'], 'aspect': ['sushi', 'service'], 'position': [[4], [8]], 'sentiment': ['Positive', 'Positive']}
# {'sentence': 'the entire staff was extremely accomodating and tended to my every need .', 'IOB': ['O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'entire', 'staff', 'was', 'extremely', 'accomodating', 'and', 'tended', 'to', 'my', 'every', 'need', '.'], 'aspect': ['staff'], 'position': [[3]], 'sentiment': ['Positive']}
# {'sentence': "i ' ve been to this restaurant over a dozen times with no complaints to date .", 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['i', "'", 've', 'been', 'to', 'this', 'restaurant', 'over', 'a', 'dozen', 'times', 'with', 'no', 'complaints', 'to', 'date', '.'], 'aspect': ['restaurant'], 'position': [[7]], 'sentiment': ['Positive']}
# {'sentence': 'the owner is belligerent to guests that have a complaint .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'owner', 'is', 'belligerent', 'to', 'guests', 'that', 'have', 'a', 'complaint', '.'], 'aspect': ['owner'], 'position': [[2]], 'sentiment': ['Negative']}
# {'sentence': 'good food !', 'IOB': ['O', 'B-ASP', 'O'], 'tokens': ['good', 'food', '!'], 'aspect': ['food'], 'position': [[2]], 'sentiment': ['Positive']}
# {'sentence': 'this is a great place to get a delicious meal .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['this', 'is', 'a', 'great', 'place', 'to', 'get', 'a', 'delicious', 'meal', '.'], 'aspect': ['meal'], 'position': [[10]], 'sentiment': ['Positive']}
# {'sentence': 'the staff is pretty friendly .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'staff', 'is', 'pretty', 'friendly', '.'], 'aspect': ['staff'], 'position': [[2]], 'sentiment': ['Positive']}
# {'sentence': 'the onion rings are great !', 'IOB': ['O', 'B-ASP', 'I-ASP', 'O', 'O', 'O'], 'tokens': ['the', 'onion', 'rings', 'are', 'great', '!'], 'aspect': ['onion rings'], 'position': [[2, 3]], 'sentiment': ['Positive']}
# {'sentence': '– i was highly disappointed in the food at pagoda .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'B-ASP', 'O'], 'tokens': ['–', 'i', 'was', 'highly', 'disappointed', 'in', 'the', 'food', 'at', 'pagoda', '.'], 'aspect': ['food', 'pagoda'], 'position': [[8], [10]], 'sentiment': ['Negative', 'Neutral']}
# {'sentence': 'the lemon chicken tasted like sticky sweet donuts and the honey walnut prawns , the few they actually give you . . . . . were not good .', 'IOB': ['O', 'B-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'B-ASP', 'I-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'lemon', 'chicken', 'tasted', 'like', 'sticky', 'sweet', 'donuts', 'and', 'the', 'honey', 'walnut', 'prawns', ',', 'the', 'few', 'they', 'actually', 'give', 'you', '.', '.', '.', '.', '.', 'were', 'not', 'good', '.'], 'aspect': ['lemon chicken', 'donuts', 'honey walnut prawns'], 'position': [[2, 3], [8], [11, 12, 13]], 'sentiment': ['Negative', 'Positive', 'Neutral']}
# {'sentence': 'nice ambience , but highly overrated place .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['nice', 'ambience', ',', 'but', 'highly', 'overrated', 'place', '.'], 'aspect': ['ambience', 'place'], 'position': [[2], [7]], 'sentiment': ['Positive', 'Negative']}
# {'sentence': 'worst service i ever had', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O'], 'tokens': ['worst', 'service', 'i', 'ever', 'had'], 'aspect': ['service'], 'position': [[2]], 'sentiment': ['Negative']}
# {'sentence': 'everyone that sat in the back outside agreed that it was the worst service we had ever received .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['everyone', 'that', 'sat', 'in', 'the', 'back', 'outside', 'agreed', 'that', 'it', 'was', 'the', 'worst', 'service', 'we', 'had', 'ever', 'received', '.'], 'aspect': ['outside', 'service'], 'position': [[7], [14]], 'sentiment': ['Neutral', 'Negative']}
# {'sentence': 'our waiter was non - existent and after our food finally arrived over an hour after we ordered , we were not given any water or utensils .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O'], 'tokens': ['our', 'waiter', 'was', 'non', '-', 'existent', 'and', 'after', 'our', 'food', 'finally', 'arrived', 'over', 'an', 'hour', 'after', 'we', 'ordered', ',', 'we', 'were', 'not', 'given', 'any', 'water', 'or', 'utensils', '.'], 'aspect': ['waiter', 'food', 'water'], 'position': [[2], [10], [25]], 'sentiment': ['Negative', 'Neutral', 'Neutral']}
# {'sentence': 'i complained to the manager , but he was not even apologetic .', 'IOB': ['O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['i', 'complained', 'to', 'the', 'manager', ',', 'but', 'he', 'was', 'not', 'even', 'apologetic', '.'], 'aspect': ['manager'], 'position': [[5]], 'sentiment': ['Negative']}
# {'sentence': 'fabulous italian food !', 'IOB': ['O', 'B-ASP', 'I-ASP', 'O'], 'tokens': ['fabulous', 'italian', 'food', '!'], 'aspect': ['italian food'], 'position': [[2, 3]], 'sentiment': ['Positive']}
# {'sentence': '– i highly recommend mioposto .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['–', 'i', 'highly', 'recommend', 'mioposto', '.'], 'aspect': [], 'position': [], 'sentiment': []}
# {'sentence': 'i am so happy to have a wonderful italian restaurant in my neighborhood .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'O', 'O', 'O'], 'tokens': ['i', 'am', 'so', 'happy', 'to', 'have', 'a', 'wonderful', 'italian', 'restaurant', 'in', 'my', 'neighborhood', '.'], 'aspect': ['italian restaurant'], 'position': [[9, 10]], 'sentiment': ['Positive']}
# {'sentence': 'the wine list is wonderful and the food reminds me of my recent trip to italy .', 'IOB': ['O', 'B-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'wine', 'list', 'is', 'wonderful', 'and', 'the', 'food', 'reminds', 'me', 'of', 'my', 'recent', 'trip', 'to', 'italy', '.'], 'aspect': ['wine list', 'food'], 'position': [[2, 3], [8]], 'sentiment': ['Positive', 'Positive']}
# {'sentence': 'i love this restaurant', 'IOB': ['O', 'O', 'O', 'B-ASP'], 'tokens': ['i', 'love', 'this', 'restaurant'], 'aspect': ['restaurant'], 'position': [[4]], 'sentiment': ['Positive']}
# {'sentence': '– i will never forget the amazing meal , service , and ambiance i experience at this restaurant .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'B-ASP', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['–', 'i', 'will', 'never', 'forget', 'the', 'amazing', 'meal', ',', 'service', ',', 'and', 'ambiance', 'i', 'experience', 'at', 'this', 'restaurant', '.'], 'aspect': ['meal', 'service', 'ambiance'], 'position': [[8], [10], [13]], 'sentiment': ['Positive', 'Positive', 'Positive']}
# {'sentence': 'the wine list is incredible and extensive and diverse , the food is all incredible and the staff was all very nice , good at their jobs and cultured .', 'IOB': ['O', 'B-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'wine', 'list', 'is', 'incredible', 'and', 'extensive', 'and', 'diverse', ',', 'the', 'food', 'is', 'all', 'incredible', 'and', 'the', 'staff', 'was', 'all', 'very', 'nice', ',', 'good', 'at', 'their', 'jobs', 'and', 'cultured', '.'], 'aspect': ['wine list', 'food', 'staff'], 'position': [[2, 3], [12], [18]], 'sentiment': ['Positive', 'Positive', 'Positive']}
# {'sentence': 'i have not a bad thing to say about this place .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['i', 'have', 'not', 'a', 'bad', 'thing', 'to', 'say', 'about', 'this', 'place', '.'], 'aspect': ['place'], 'position': [[11]], 'sentiment': ['Positive']}
# {'sentence': 'the food was great !', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O'], 'tokens': ['the', 'food', 'was', 'great', '!'], 'aspect': ['food'], 'position': [[2]], 'sentiment': ['Positive']}
# {'sentence': "it ' s * very * reasonably priced , esp for the quality of the food .", 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['it', "'", 's', '*', 'very', '*', 'reasonably', 'priced', ',', 'esp', 'for', 'the', 'quality', 'of', 'the', 'food', '.'], 'aspect': ['priced', 'quality', 'food'], 'position': [[8], [13], [16]], 'sentiment': ['Positive', 'Positive', 'Neutral']}
# {'sentence': 'i had the kafta plate and it was perfect .', 'IOB': ['O', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['i', 'had', 'the', 'kafta', 'plate', 'and', 'it', 'was', 'perfect', '.'], 'aspect': ['kafta plate'], 'position': [[4, 5]], 'sentiment': ['Positive']}
# {'sentence': 'finally a meal that you will remember for a long time !', 'IOB': ['O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['finally', 'a', 'meal', 'that', 'you', 'will', 'remember', 'for', 'a', 'long', 'time', '!'], 'aspect': ['meal'], 'position': [[3]], 'sentiment': ['Positive']}
# {'sentence': '– in a age of incremental cost cutting in restaurants , its nice to see a place that bucks that trend , and just plain delivers high quality food and good service , period .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'B-ASP', 'O', 'O', 'O'], 'tokens': ['–', 'in', 'a', 'age', 'of', 'incremental', 'cost', 'cutting', 'in', 'restaurants', ',', 'its', 'nice', 'to', 'see', 'a', 'place', 'that', 'bucks', 'that', 'trend', ',', 'and', 'just', 'plain', 'delivers', 'high', 'quality', 'food', 'and', 'good', 'service', ',', 'period', '.'], 'aspect': ['food', 'service'], 'position': [[29], [32]], 'sentiment': ['Positive', 'Positive']}
# {'sentence': 'this is the place to relax and enjoy the finest quality food the industry can offer .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'B-ASP', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['this', 'is', 'the', 'place', 'to', 'relax', 'and', 'enjoy', 'the', 'finest', 'quality', 'food', 'the', 'industry', 'can', 'offer', '.'], 'aspect': ['quality food'], 'position': [[11, 12]], 'sentiment': ['Positive']}
# {'sentence': 'caution - its real food for people who love the best .', 'IOB': ['O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['caution', '-', 'its', 'real', 'food', 'for', 'people', 'who', 'love', 'the', 'best', '.'], 'aspect': ['food'], 'position': [[5]], 'sentiment': ['Positive']}
# {'sentence': 'i liked the atmosphere very much but the food was not worth the price .', 'IOB': ['O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['i', 'liked', 'the', 'atmosphere', 'very', 'much', 'but', 'the', 'food', 'was', 'not', 'worth', 'the', 'price', '.'], 'aspect': ['atmosphere', 'food', 'price'], 'position': [[4], [9], [14]], 'sentiment': ['Positive', 'Negative', 'Negative']}
# {'sentence': 'i may not be a sushi guru but i can tell you that the food here is just okay and that there is not much else to it .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['i', 'may', 'not', 'be', 'a', 'sushi', 'guru', 'but', 'i', 'can', 'tell', 'you', 'that', 'the', 'food', 'here', 'is', 'just', 'okay', 'and', 'that', 'there', 'is', 'not', 'much', 'else', 'to', 'it', '.'], 'aspect': ['sushi', 'food'], 'position': [[6], [15]], 'sentiment': ['Negative', 'Neutral']}
# {'sentence': "rice is too dry , tuna was n ' t so fresh either .", 'IOB': ['B-ASP', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['rice', 'is', 'too', 'dry', ',', 'tuna', 'was', 'n', "'", 't', 'so', 'fresh', 'either', '.'], 'aspect': ['rice', 'tuna'], 'position': [[1], [6]], 'sentiment': ['Negative', 'Negative']}
# {'sentence': 'i have eaten here three times and have found the quality and variety of the fish to be excellent .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'B-ASP', 'O', 'O', 'I-ASP', 'O', 'O', 'O', 'O'], 'tokens': ['i', 'have', 'eaten', 'here', 'three', 'times', 'and', 'have', 'found', 'the', 'quality', 'and', 'variety', 'of', 'the', 'fish', 'to', 'be', 'excellent', '.'], 'aspect': ['quality', 'variety', 'fish'], 'position': [[11], [13], [16]], 'sentiment': ['Positive', 'Positive', 'Positive']}
# {'sentence': 'however , the value and service are both severely lacking .', 'IOB': ['O', 'O', 'O', 'B-ASP', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['however', ',', 'the', 'value', 'and', 'service', 'are', 'both', 'severely', 'lacking', '.'], 'aspect': ['value', 'service'], 'position': [[4], [6]], 'sentiment': ['Negative', 'Negative']}
# {'sentence': 'furthermore , while the fish is unquestionably fresh , rolls tend to be inexplicably bland .', 'IOB': ['O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['furthermore', ',', 'while', 'the', 'fish', 'is', 'unquestionably', 'fresh', ',', 'rolls', 'tend', 'to', 'be', 'inexplicably', 'bland', '.'], 'aspect': ['fish', 'rolls'], 'position': [[5], [10]], 'sentiment': ['Positive', 'Negative']}
# {'sentence': 'the service ranges from mediocre to offensive .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'service', 'ranges', 'from', 'mediocre', 'to', 'offensive', '.'], 'aspect': ['service'], 'position': [[2]], 'sentiment': ['Negative']}
# {'sentence': 'on a recent trip , our waiter was extremely dismissive , while no less than three staff members waited hand - and - foot on a pair of japanese girls seated nearby .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['on', 'a', 'recent', 'trip', ',', 'our', 'waiter', 'was', 'extremely', 'dismissive', ',', 'while', 'no', 'less', 'than', 'three', 'staff', 'members', 'waited', 'hand', '-', 'and', '-', 'foot', 'on', 'a', 'pair', 'of', 'japanese', 'girls', 'seated', 'nearby', '.'], 'aspect': ['waiter', 'staff members'], 'position': [[7], [17, 18]], 'sentiment': ['Negative', 'Negative']}
# {'sentence': 'freshest sushi – i love this restaurant .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['freshest', 'sushi', '–', 'i', 'love', 'this', 'restaurant', '.'], 'aspect': ['sushi'], 'position': [[2]], 'sentiment': ['Positive']}
# {'sentence': 'freshest sushi – i love this restaurant .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['freshest', 'sushi', '–', 'i', 'love', 'this', 'restaurant', '.'], 'aspect': ['sushi'], 'position': [[2]], 'sentiment': ['Positive']}
# {'sentence': 'they pay such detail to everything from miso soup to complex rolls .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['they', 'pay', 'such', 'detail', 'to', 'everything', 'from', 'miso', 'soup', 'to', 'complex', 'rolls', '.'], 'aspect': ['miso soup', 'rolls'], 'position': [[8, 9], [12]], 'sentiment': ['Positive', 'Negative']}
# {'sentence': 'the sashimi was the freshest and most tender i have ever tasted .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'sashimi', 'was', 'the', 'freshest', 'and', 'most', 'tender', 'i', 'have', 'ever', 'tasted', '.'], 'aspect': ['sashimi'], 'position': [[2]], 'sentiment': ['Positive']}
# {'sentence': 'their apps are all delicious .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O'], 'tokens': ['their', 'apps', 'are', 'all', 'delicious', '.'], 'aspect': ['apps'], 'position': [[2]], 'sentiment': ['Positive']}
# {'sentence': 'the only drawback is that this place is really expensive and the portions are on the small side .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'only', 'drawback', 'is', 'that', 'this', 'place', 'is', 'really', 'expensive', 'and', 'the', 'portions', 'are', 'on', 'the', 'small', 'side', '.'], 'aspect': ['place', 'portions'], 'position': [[7], [13]], 'sentiment': ['Negative', 'Negative']}
# {'sentence': 'but the space is small and lovely , and the service is helpful .', 'IOB': ['O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O'], 'tokens': ['but', 'the', 'space', 'is', 'small', 'and', 'lovely', ',', 'and', 'the', 'service', 'is', 'helpful', '.'], 'aspect': ['space', 'service'], 'position': [[3], [11]], 'sentiment': ['Negative', 'Positive']}
# {'sentence': '– the food was not great & the waiters were rude .', 'IOB': ['O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O'], 'tokens': ['–', 'the', 'food', 'was', 'not', 'great', '&', 'the', 'waiters', 'were', 'rude', '.'], 'aspect': ['food', 'waiters'], 'position': [[3], [9]], 'sentiment': ['Neutral', 'Negative']}
# {'sentence': 'great service', 'IOB': ['O', 'B-ASP'], 'tokens': ['great', 'service'], 'aspect': ['service'], 'position': [[2]], 'sentiment': ['Positive']}
# {'sentence': 'my service was stellar !', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O'], 'tokens': ['my', 'service', 'was', 'stellar', '!'], 'aspect': ['service'], 'position': [[2]], 'sentiment': ['Positive']}
# {'sentence': 'the bus boy even spotted that my table was shaking a stabilized it for me .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'bus', 'boy', 'even', 'spotted', 'that', 'my', 'table', 'was', 'shaking', 'a', 'stabilized', 'it', 'for', 'me', '.'], 'aspect': ['table'], 'position': [[8]], 'sentiment': ['Neutral']}
# {'sentence': 'food was fine , with a some little - tastier - than - normal salsa .', 'IOB': ['B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['food', 'was', 'fine', ',', 'with', 'a', 'some', 'little', '-', 'tastier', '-', 'than', '-', 'normal', 'salsa', '.'], 'aspect': ['food', 'salsa'], 'position': [[1], [15]], 'sentiment': ['Positive', 'Positive']}
# {'sentence': 'the food was great , the margaritas too but the waitress was too busy being nice to her other larger party than to take better care of my friend and me .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'food', 'was', 'great', ',', 'the', 'margaritas', 'too', 'but', 'the', 'waitress', 'was', 'too', 'busy', 'being', 'nice', 'to', 'her', 'other', 'larger', 'party', 'than', 'to', 'take', 'better', 'care', 'of', 'my', 'friend', 'and', 'me', '.'], 'aspect': ['food', 'margaritas', 'waitress'], 'position': [[2], [7], [11]], 'sentiment': ['Positive', 'Positive', 'Negative']}
# {'sentence': 'mama mia – i live in the neighborhood and feel lucky to live by such a great pizza place .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O'], 'tokens': ['mama', 'mia', '–', 'i', 'live', 'in', 'the', 'neighborhood', 'and', 'feel', 'lucky', 'to', 'live', 'by', 'such', 'a', 'great', 'pizza', 'place', '.'], 'aspect': ['pizza place'], 'position': [[18, 19]], 'sentiment': ['Positive']}
# {'sentence': "the only problem is you really have to warm up the pizza before it ' s edible , even when you order ahead .", 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'only', 'problem', 'is', 'you', 'really', 'have', 'to', 'warm', 'up', 'the', 'pizza', 'before', 'it', "'", 's', 'edible', ',', 'even', 'when', 'you', 'order', 'ahead', '.'], 'aspect': ['pizza'], 'position': [[12]], 'sentiment': ['Negative']}
# {'sentence': 'best sushi in town .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O'], 'tokens': ['best', 'sushi', 'in', 'town', '.'], 'aspect': ['sushi'], 'position': [[2]], 'sentiment': ['Positive']}
# {'sentence': 'the best calamari in seattle !', 'IOB': ['O', 'O', 'B-ASP', 'O', 'O', 'O'], 'tokens': ['the', 'best', 'calamari', 'in', 'seattle', '!'], 'aspect': ['calamari'], 'position': [[3]], 'sentiment': ['Positive']}
# {'sentence': '– . . . and the best summertime deck experience - - they will even bring you a blanket if you get cold in the seattle evening weather .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'B-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['–', '.', '.', '.', 'and', 'the', 'best', 'summertime', 'deck', 'experience', '-', '-', 'they', 'will', 'even', 'bring', 'you', 'a', 'blanket', 'if', 'you', 'get', 'cold', 'in', 'the', 'seattle', 'evening', 'weather', '.'], 'aspect': ['summertime deck experience', 'weather'], 'position': [[8, 9, 10], [28]], 'sentiment': ['Positive', 'Neutral']}
# {'sentence': 'a perfect place to take out of town guests any time of the year .', 'IOB': ['O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['a', 'perfect', 'place', 'to', 'take', 'out', 'of', 'town', 'guests', 'any', 'time', 'of', 'the', 'year', '.'], 'aspect': ['place'], 'position': [[3]], 'sentiment': ['Positive']}
# {'sentence': 'endless fun , awesome music , great staff ! ! !', 'IOB': ['O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'B-ASP', 'O', 'O', 'O'], 'tokens': ['endless', 'fun', ',', 'awesome', 'music', ',', 'great', 'staff', '!', '!', '!'], 'aspect': ['music', 'staff'], 'position': [[5], [8]], 'sentiment': ['Positive', 'Positive']}
# {'sentence': '– by far the best bar in the east village . . .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['–', 'by', 'far', 'the', 'best', 'bar', 'in', 'the', 'east', 'village', '.', '.', '.'], 'aspect': ['bar'], 'position': [[6]], 'sentiment': ['Positive']}
# {'sentence': 'every time " 0 - sixtynine " is called the bartender buys everyone drinks !', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['every', 'time', '"', '0', '-', 'sixtynine', '"', 'is', 'called', 'the', 'bartender', 'buys', 'everyone', 'drinks', '!'], 'aspect': ['bartender', 'drinks'], 'position': [[11], [14]], 'sentiment': ['Negative', 'Neutral']}
# {'sentence': 'great draft and bottle selection and the pizza rocks .', 'IOB': ['O', 'B-ASP', 'O', 'B-ASP', 'I-ASP', 'O', 'O', 'B-ASP', 'O', 'O'], 'tokens': ['great', 'draft', 'and', 'bottle', 'selection', 'and', 'the', 'pizza', 'rocks', '.'], 'aspect': ['draft', 'bottle selection', 'pizza'], 'position': [[2], [4, 5], [8]], 'sentiment': ['Positive', 'Positive', 'Positive']}
# {'sentence': "definitely has one of the best jukebox ' s i ' ve seen in a long long time .", 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['definitely', 'has', 'one', 'of', 'the', 'best', 'jukebox', "'", 's', 'i', "'", 've', 'seen', 'in', 'a', 'long', 'long', 'time', '.'], 'aspect': ['jukebox'], 'position': [[7]], 'sentiment': ['Positive']}
# {'sentence': 'the food is great , the bartenders go that extra mile .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'food', 'is', 'great', ',', 'the', 'bartenders', 'go', 'that', 'extra', 'mile', '.'], 'aspect': ['food', 'bartenders'], 'position': [[2], [7]], 'sentiment': ['Positive', 'Positive']}
# {'sentence': 'the owners are great fun and the beer selection is worth staying for .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'owners', 'are', 'great', 'fun', 'and', 'the', 'beer', 'selection', 'is', 'worth', 'staying', 'for', '.'], 'aspect': ['owners', 'beer selection'], 'position': [[2], [8, 9]], 'sentiment': ['Positive', 'Positive']}
# {'sentence': 'and the upstairs is a great place to hang out .', 'IOB': ['O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['and', 'the', 'upstairs', 'is', 'a', 'great', 'place', 'to', 'hang', 'out', '.'], 'aspect': ['upstairs'], 'position': [[3]], 'sentiment': ['Positive']}
# {'sentence': 'not alot of smoking places left in new york , but i have found my favorite smoking balconey in the city .', 'IOB': ['O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['not', 'alot', 'of', 'smoking', 'places', 'left', 'in', 'new', 'york', ',', 'but', 'i', 'have', 'found', 'my', 'favorite', 'smoking', 'balconey', 'in', 'the', 'city', '.'], 'aspect': ['places'], 'position': [[5]], 'sentiment': ['Neutral']}
# {'sentence': 'the sushi here is delicious !', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'sushi', 'here', 'is', 'delicious', '!'], 'aspect': ['sushi'], 'position': [[2]], 'sentiment': ['Positive']}
# {'sentence': 'they have a wide variety of fish and they even list which oceans they come from ; atlantic or pacific .', 'IOB': ['O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['they', 'have', 'a', 'wide', 'variety', 'of', 'fish', 'and', 'they', 'even', 'list', 'which', 'oceans', 'they', 'come', 'from', ';', 'atlantic', 'or', 'pacific', '.'], 'aspect': ['variety of fish', 'pacific'], 'position': [[5, 6, 7], [20]], 'sentiment': ['Positive', 'Neutral']}
# {'sentence': "i ' ve had the jellyfish , horse mackerel , blue fin tuna and the sake ikura roll among others , and they were all good .", 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['i', "'", 've', 'had', 'the', 'jellyfish', ',', 'horse', 'mackerel', ',', 'blue', 'fin', 'tuna', 'and', 'the', 'sake', 'ikura', 'roll', 'among', 'others', ',', 'and', 'they', 'were', 'all', 'good', '.'], 'aspect': ['horse mackerel', 'sake ikura roll'], 'position': [[8, 9], [16, 17, 18]], 'sentiment': ['Neutral', 'Positive']}
# {'sentence': 'my only negative comment is that i wish the pieces were a little bigger .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['my', 'only', 'negative', 'comment', 'is', 'that', 'i', 'wish', 'the', 'pieces', 'were', 'a', 'little', 'bigger', '.'], 'aspect': ['pieces'], 'position': [[10]], 'sentiment': ['Negative']}
# {'sentence': 'the decor is rustic , traditional japanese .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['the', 'decor', 'is', 'rustic', ',', 'traditional', 'japanese', '.'], 'aspect': ['decor', 'japanese'], 'position': [[2], [7]], 'sentiment': ['Neutral', 'Neutral']}
# {'sentence': 'the crowd is mixed yuppies , young and old .', 'IOB': ['O', 'B-ASP', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'crowd', 'is', 'mixed', 'yuppies', ',', 'young', 'and', 'old', '.'], 'aspect': ['crowd', 'mixed'], 'position': [[2], [4]], 'sentiment': ['Neutral', 'Neutral']}
# {'sentence': 'the service was courteous and attentive .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'service', 'was', 'courteous', 'and', 'attentive', '.'], 'aspect': ['service'], 'position': [[2]], 'sentiment': ['Positive']}
# {'sentence': 'mediocre food', 'IOB': ['O', 'B-ASP'], 'tokens': ['mediocre', 'food'], 'aspect': ['food'], 'position': [[2]], 'sentiment': ['Neutral']}
# {'sentence': 'the outside patio area has an abbreviated menu .', 'IOB': ['O', 'B-ASP', 'I-ASP', 'I-ASP', 'O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['the', 'outside', 'patio', 'area', 'has', 'an', 'abbreviated', 'menu', '.'], 'aspect': ['outside patio area', 'menu'], 'position': [[2, 3, 4], [8]], 'sentiment': ['Neutral', 'Neutral']}
# {'sentence': 'my g / f and i both agreed the food was very mediocre especially considering the price .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['my', 'g', '/', 'f', 'and', 'i', 'both', 'agreed', 'the', 'food', 'was', 'very', 'mediocre', 'especially', 'considering', 'the', 'price', '.'], 'aspect': ['food', 'price'], 'position': [[10], [17]], 'sentiment': ['Negative', 'Neutral']}
# {'sentence': 'we are locals , and get the feeling the only way this place survives with such average food is because most customers are probably one - time customer tourists .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['we', 'are', 'locals', ',', 'and', 'get', 'the', 'feeling', 'the', 'only', 'way', 'this', 'place', 'survives', 'with', 'such', 'average', 'food', 'is', 'because', 'most', 'customers', 'are', 'probably', 'one', '-', 'time', 'customer', 'tourists', '.'], 'aspect': ['food'], 'position': [[18]], 'sentiment': ['Negative']}
# {'sentence': 'service was decent .', 'IOB': ['B-ASP', 'O', 'O', 'O'], 'tokens': ['service', 'was', 'decent', '.'], 'aspect': ['service'], 'position': [[1]], 'sentiment': ['Positive']}
# {'sentence': 'drinks were good .', 'IOB': ['B-ASP', 'O', 'O', 'O'], 'tokens': ['drinks', 'were', 'good', '.'], 'aspect': ['drinks'], 'position': [[1]], 'sentiment': ['Positive']}
# {'sentence': "unless you are just stopping in for a few drinks i would n ' t recommend going here .", 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['unless', 'you', 'are', 'just', 'stopping', 'in', 'for', 'a', 'few', 'drinks', 'i', 'would', 'n', "'", 't', 'recommend', 'going', 'here', '.'], 'aspect': ['drinks'], 'position': [[10]], 'sentiment': ['Negative']}
# {'sentence': 'excellent food , nice ambience , fairly expensive', 'IOB': ['O', 'B-ASP', 'O', 'O', 'B-ASP', 'O', 'O', 'O'], 'tokens': ['excellent', 'food', ',', 'nice', 'ambience', ',', 'fairly', 'expensive'], 'aspect': ['food', 'ambience'], 'position': [[2], [5]], 'sentiment': ['Positive', 'Positive']}
# {'sentence': '– i loved the pumpkin ravioli and the goat cheese gnocchi ( 5 big ones to a plate instead of 2 0 or so little gnocchis ) and my sister loved her filet mignon on top of spinach and mashed potatoes .', 'IOB': ['O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'O', 'B-ASP', 'I-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'O', 'O', 'B-ASP', 'O', 'B-ASP', 'I-ASP', 'O'], 'tokens': ['–', 'i', 'loved', 'the', 'pumpkin', 'ravioli', 'and', 'the', 'goat', 'cheese', 'gnocchi', '(', '5', 'big', 'ones', 'to', 'a', 'plate', 'instead', 'of', '2', '0', 'or', 'so', 'little', 'gnocchis', ')', 'and', 'my', 'sister', 'loved', 'her', 'filet', 'mignon', 'on', 'top', 'of', 'spinach', 'and', 'mashed', 'potatoes', '.'], 'aspect': ['pumpkin ravioli', 'goat cheese gnocchi', 'filet mignon', 'spinach', 'mashed potatoes'], 'position': [[5, 6], [9, 10, 11], [33, 34], [38], [40, 41]], 'sentiment': ['Positive', 'Positive', 'Positive', 'Neutral', 'Neutral']}
# {'sentence': 'the ambiance was a peaceful and relaxing break amongst all the kids running around in downtown disney .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'ambiance', 'was', 'a', 'peaceful', 'and', 'relaxing', 'break', 'amongst', 'all', 'the', 'kids', 'running', 'around', 'in', 'downtown', 'disney', '.'], 'aspect': ['ambiance'], 'position': [[2]], 'sentiment': ['Positive']}
# {'sentence': 'it was romantic - and even nice even with my sister , reminded me of italy , and had artwork and music that kept up the feeling of being in a mediterrean villa .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['it', 'was', 'romantic', '-', 'and', 'even', 'nice', 'even', 'with', 'my', 'sister', ',', 'reminded', 'me', 'of', 'italy', ',', 'and', 'had', 'artwork', 'and', 'music', 'that', 'kept', 'up', 'the', 'feeling', 'of', 'being', 'in', 'a', 'mediterrean', 'villa', '.'], 'aspect': ['artwork', 'music'], 'position': [[20], [22]], 'sentiment': ['Positive', 'Positive']}
# {'sentence': 'best indian food in l . a .', 'IOB': ['O', 'B-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['best', 'indian', 'food', 'in', 'l', '.', 'a', '.'], 'aspect': ['indian food'], 'position': [[2, 3]], 'sentiment': ['Positive']}
# {'sentence': 'the chicken curry and chicken tikka masala are my favorite meat dishes .', 'IOB': ['O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'I-ASP', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O'], 'tokens': ['the', 'chicken', 'curry', 'and', 'chicken', 'tikka', 'masala', 'are', 'my', 'favorite', 'meat', 'dishes', '.'], 'aspect': ['chicken tikka masala', 'meat dishes'], 'position': [[5, 6, 7], [11, 12]], 'sentiment': ['Positive', 'Positive']}
# {'sentence': 'the chana masala ( garbanzo beans ) are also excellent .', 'IOB': ['O', 'B-ASP', 'I-ASP', 'I-ASP', 'I-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'chana', 'masala', '(', 'garbanzo', 'beans', ')', 'are', 'also', 'excellent', '.'], 'aspect': ['chana masala ( garbanzo beans'], 'position': [[2, 3, 4, 5, 6]], 'sentiment': ['Positive']}
# {'sentence': "it ' s located in a strip mall near the beverly center , not the greatest location , but the food keeps me coming back for more .", 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['it', "'", 's', 'located', 'in', 'a', 'strip', 'mall', 'near', 'the', 'beverly', 'center', ',', 'not', 'the', 'greatest', 'location', ',', 'but', 'the', 'food', 'keeps', 'me', 'coming', 'back', 'for', 'more', '.'], 'aspect': ['location', 'food'], 'position': [[17], [21]], 'sentiment': ['Negative', 'Positive']}
# {'sentence': 'never too crowded and always great service .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['never', 'too', 'crowded', 'and', 'always', 'great', 'service', '.'], 'aspect': ['service'], 'position': [[7]], 'sentiment': ['Positive']}
# {'sentence': 'i think i have probably tried each item on their menu at least once it is all excellent .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['i', 'think', 'i', 'have', 'probably', 'tried', 'each', 'item', 'on', 'their', 'menu', 'at', 'least', 'once', 'it', 'is', 'all', 'excellent', '.'], 'aspect': ['menu'], 'position': [[11]], 'sentiment': ['Neutral']}
# {'sentence': 'i can highly recommend their various saag and paneer and korma .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['i', 'can', 'highly', 'recommend', 'their', 'various', 'saag', 'and', 'paneer', 'and', 'korma', '.'], 'aspect': ['saag'], 'position': [[7]], 'sentiment': ['Positive']}
# {'sentence': 'i appreciate their delivery too .', 'IOB': ['O', 'O', 'O', 'B-ASP', 'O', 'O'], 'tokens': ['i', 'appreciate', 'their', 'delivery', 'too', '.'], 'aspect': ['delivery'], 'position': [[4]], 'sentiment': ['Positive']}
# {'sentence': 'nice food but no spice !', 'IOB': ['O', 'B-ASP', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['nice', 'food', 'but', 'no', 'spice', '!'], 'aspect': ['food', 'spice'], 'position': [[2], [5]], 'sentiment': ['Negative', 'Negative']}
# {'sentence': '– i really enjoyed my meal here .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O'], 'tokens': ['–', 'i', 'really', 'enjoyed', 'my', 'meal', 'here', '.'], 'aspect': ['meal'], 'position': [[6]], 'sentiment': ['Positive']}
# {'sentence': 'i had yummy lamb korma , saag paneer , samosas , naan , etc .', 'IOB': ['O', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'B-ASP', 'I-ASP', 'O', 'B-ASP', 'O', 'B-ASP', 'O', 'O', 'O'], 'tokens': ['i', 'had', 'yummy', 'lamb', 'korma', ',', 'saag', 'paneer', ',', 'samosas', ',', 'naan', ',', 'etc', '.'], 'aspect': ['lamb korma', 'saag paneer', 'samosas', 'naan'], 'position': [[4, 5], [7, 8], [10], [12]], 'sentiment': ['Positive', 'Neutral', 'Neutral', 'Neutral']}
# {'sentence': 'the food was all good but it was way too mild .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'food', 'was', 'all', 'good', 'but', 'it', 'was', 'way', 'too', 'mild', '.'], 'aspect': ['food'], 'position': [[2]], 'sentiment': ['Positive']}
# {'sentence': 'i should have thought to bring it up but never expected the food to be that mild .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['i', 'should', 'have', 'thought', 'to', 'bring', 'it', 'up', 'but', 'never', 'expected', 'the', 'food', 'to', 'be', 'that', 'mild', '.'], 'aspect': ['food'], 'position': [[13]], 'sentiment': ['Positive']}
# {'sentence': "the naan was some of the best i ' ve had and i really enjoyed the bhartha , not too tomatoey .", 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'naan', 'was', 'some', 'of', 'the', 'best', 'i', "'", 've', 'had', 'and', 'i', 'really', 'enjoyed', 'the', 'bhartha', ',', 'not', 'too', 'tomatoey', '.'], 'aspect': ['naan', 'bhartha'], 'position': [[2], [17]], 'sentiment': ['Positive', 'Positive']}
# {'sentence': 'even the chickpeas , which i normally find too dry , were good .', 'IOB': ['O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['even', 'the', 'chickpeas', ',', 'which', 'i', 'normally', 'find', 'too', 'dry', ',', 'were', 'good', '.'], 'aspect': ['chickpeas'], 'position': [[3]], 'sentiment': ['Positive']}
# {'sentence': "– i do n ' t understand how i was a stranger to this place for so long . . . the fajita salad , the colorado , the fajitas - everything is delicious .", 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['–', 'i', 'do', 'n', "'", 't', 'understand', 'how', 'i', 'was', 'a', 'stranger', 'to', 'this', 'place', 'for', 'so', 'long', '.', '.', '.', 'the', 'fajita', 'salad', ',', 'the', 'colorado', ',', 'the', 'fajitas', '-', 'everything', 'is', 'delicious', '.'], 'aspect': ['fajita salad', 'fajitas'], 'position': [[23, 24], [30]], 'sentiment': ['Positive', 'Positive']}
# {'sentence': 'i love the warm & cosy environment .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['i', 'love', 'the', 'warm', '&', 'cosy', 'environment', '.'], 'aspect': ['environment'], 'position': [[7]], 'sentiment': ['Positive']}
# {'sentence': "i just found out that you can have the place to yourself on nights and weekends for a private party - ca n ' t wait to celebrate my next birthday there .", 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['i', 'just', 'found', 'out', 'that', 'you', 'can', 'have', 'the', 'place', 'to', 'yourself', 'on', 'nights', 'and', 'weekends', 'for', 'a', 'private', 'party', '-', 'ca', 'n', "'", 't', 'wait', 'to', 'celebrate', 'my', 'next', 'birthday', 'there', '.'], 'aspect': ['place'], 'position': [[10]], 'sentiment': ['Positive']}
# {'sentence': 'best restaurant in the world , great decor , great customer service , friendly manager', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'O', 'B-ASP'], 'tokens': ['best', 'restaurant', 'in', 'the', 'world', ',', 'great', 'decor', ',', 'great', 'customer', 'service', ',', 'friendly', 'manager'], 'aspect': ['decor', 'customer service', 'manager'], 'position': [[8], [11, 12], [15]], 'sentiment': ['Positive', 'Positive', 'Positive']}
# {'sentence': 'i am never disappointed with there food .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['i', 'am', 'never', 'disappointed', 'with', 'there', 'food', '.'], 'aspect': ['food'], 'position': [[7]], 'sentiment': ['Positive']}
# {'sentence': 'the atmosphere is great .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O'], 'tokens': ['the', 'atmosphere', 'is', 'great', '.'], 'aspect': ['atmosphere'], 'position': [[2]], 'sentiment': ['Positive']}
# {'sentence': 'great lunch spot', 'IOB': ['O', 'B-ASP', 'I-ASP'], 'tokens': ['great', 'lunch', 'spot'], 'aspect': ['lunch spot'], 'position': [[2, 3]], 'sentiment': ['Positive']}
# {'sentence': '– great financial district mexican spot .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['–', 'great', 'financial', 'district', 'mexican', 'spot', '.'], 'aspect': ['spot'], 'position': [[6]], 'sentiment': ['Positive']}
# {'sentence': 'always busy , but they are good at seating you promptly and have quick service .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['always', 'busy', ',', 'but', 'they', 'are', 'good', 'at', 'seating', 'you', 'promptly', 'and', 'have', 'quick', 'service', '.'], 'aspect': ['seating', 'service'], 'position': [[9], [15]], 'sentiment': ['Neutral', 'Positive']}
# {'sentence': "everything i ' ve had here is good , taco salads , burritos , enchiladas i love this place .", 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'B-ASP', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['everything', 'i', "'", 've', 'had', 'here', 'is', 'good', ',', 'taco', 'salads', ',', 'burritos', ',', 'enchiladas', 'i', 'love', 'this', 'place', '.'], 'aspect': ['taco salads', 'burritos', 'enchiladas'], 'position': [[10, 11], [13], [15]], 'sentiment': ['Positive', 'Positive', 'Positive']}
# {'sentence': 'also have great margaritas !', 'IOB': ['O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['also', 'have', 'great', 'margaritas', '!'], 'aspect': ['margaritas'], 'position': [[4]], 'sentiment': ['Positive']}
# {'sentence': 'lebanese food ! yum !', 'IOB': ['B-ASP', 'I-ASP', 'O', 'O', 'O'], 'tokens': ['lebanese', 'food', '!', 'yum', '!'], 'aspect': ['lebanese food'], 'position': [[1, 2]], 'sentiment': ['Positive']}
# {'sentence': "– i ' ve been to open sesame only once , but i ' m still reeling from the experience ! !", 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['–', 'i', "'", 've', 'been', 'to', 'open', 'sesame', 'only', 'once', ',', 'but', 'i', "'", 'm', 'still', 'reeling', 'from', 'the', 'experience', '!', '!'], 'aspect': ['open sesame'], 'position': [[7, 8]], 'sentiment': ['Neutral']}
# {'sentence': 'the food is simply unforgettable !', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'food', 'is', 'simply', 'unforgettable', '!'], 'aspect': ['food'], 'position': [[2]], 'sentiment': ['Positive']}
# {'sentence': 'the presentation of the food was an added bonus , it looked just as great as it tasted !', 'IOB': ['O', 'B-ASP', 'I-ASP', 'I-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'presentation', 'of', 'the', 'food', 'was', 'an', 'added', 'bonus', ',', 'it', 'looked', 'just', 'as', 'great', 'as', 'it', 'tasted', '!'], 'aspect': ['presentation of the food'], 'position': [[2, 3, 4, 5]], 'sentiment': ['Positive']}
# {'sentence': 'my best friend had the chicken shawarma and she still raves about it being the best anywhere !', 'IOB': ['O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['my', 'best', 'friend', 'had', 'the', 'chicken', 'shawarma', 'and', 'she', 'still', 'raves', 'about', 'it', 'being', 'the', 'best', 'anywhere', '!'], 'aspect': ['chicken shawarma'], 'position': [[6, 7]], 'sentiment': ['Positive']}
# {'sentence': 'the staff are friendly and the decor was ethic and colorful .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'staff', 'are', 'friendly', 'and', 'the', 'decor', 'was', 'ethic', 'and', 'colorful', '.'], 'aspect': ['staff', 'decor'], 'position': [[2], [7]], 'sentiment': ['Positive', 'Positive']}
# {'sentence': 'go to open sesame ! ! !', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['go', 'to', 'open', 'sesame', '!', '!', '!'], 'aspect': [], 'position': [], 'sentiment': []}
# {'sentence': 'holy hummus !', 'IOB': ['O', 'B-ASP', 'O'], 'tokens': ['holy', 'hummus', '!'], 'aspect': ['hummus'], 'position': [[2]], 'sentiment': ['Positive']}
# ...
# {'sentence': 'to start off , approximately 8 - 1 0 oz of orange juice will cost you $ 3 .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'B-ASP', 'I-ASP', 'O', 'B-ASP', 'O', 'O', 'O', 'O'], 'tokens': ['to', 'start', 'off', ',', 'approximately', '8', '-', '1', '0', 'oz', 'of', 'orange', 'juice', 'will', 'cost', 'you', '$', '3', '.'], 'aspect': ['oz', 'orange juice', 'cost'], 'position': [[10], [12, 13], [15]], 'sentiment': ['Neutral', 'Neutral', 'Negative']}
# {'sentence': 'they serve it in a tall , skinny hour - glass shaped glass to disguise the fact that you a getting a small juice at the price of a half gallon in a supermarket .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['they', 'serve', 'it', 'in', 'a', 'tall', ',', 'skinny', 'hour', '-', 'glass', 'shaped', 'glass', 'to', 'disguise', 'the', 'fact', 'that', 'you', 'a', 'getting', 'a', 'small', 'juice', 'at', 'the', 'price', 'of', 'a', 'half', 'gallon', 'in', 'a', 'supermarket', '.'], 'aspect': ['serve', 'glass', 'juice', 'price'], 'position': [[2], [13], [24], [27]], 'sentiment': ['Positive', 'Positive', 'Negative', 'Neutral']}
# {'sentence': 'i should have just asked for the check when i saw that ; but their menu was so unique that i continued .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['i', 'should', 'have', 'just', 'asked', 'for', 'the', 'check', 'when', 'i', 'saw', 'that', ';', 'but', 'their', 'menu', 'was', 'so', 'unique', 'that', 'i', 'continued', '.'], 'aspect': ['check', 'menu'], 'position': [[8], [16]], 'sentiment': ['Neutral', 'Positive']}
# {'sentence': 'the pancakes were certainly inventive but $ 8 . 5 0 for 3 - 6 " pancakes ( one of them was more like 5 " ) in the pancake flight ( sample of 3 different pancakes ) is well over - priced .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['the', 'pancakes', 'were', 'certainly', 'inventive', 'but', '$', '8', '.', '5', '0', 'for', '3', '-', '6', '"', 'pancakes', '(', 'one', 'of', 'them', 'was', 'more', 'like', '5', '"', ')', 'in', 'the', 'pancake', 'flight', '(', 'sample', 'of', '3', 'different', 'pancakes', ')', 'is', 'well', 'over', '-', 'priced', '.'], 'aspect': ['pancakes', 'pancake flight', 'priced'], 'position': [[2], [30, 31], [43]], 'sentiment': ['Positive', 'Neutral', 'Negative']}
# {'sentence': 'the pancakes should be larger ( at least 8 " ) to justify the expense even with the unique offerings .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'pancakes', 'should', 'be', 'larger', '(', 'at', 'least', '8', '"', ')', 'to', 'justify', 'the', 'expense', 'even', 'with', 'the', 'unique', 'offerings', '.'], 'aspect': ['pancakes', 'expense'], 'position': [[2], [15]], 'sentiment': ['Neutral', 'Negative']}
# {'sentence': "on my meal i had to send back my eggs for a simple request of breaking the yokes before cooking , and would have had to send them back again if i had n ' t rejected the meal all together .", 'IOB': ['O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['on', 'my', 'meal', 'i', 'had', 'to', 'send', 'back', 'my', 'eggs', 'for', 'a', 'simple', 'request', 'of', 'breaking', 'the', 'yokes', 'before', 'cooking', ',', 'and', 'would', 'have', 'had', 'to', 'send', 'them', 'back', 'again', 'if', 'i', 'had', 'n', "'", 't', 'rejected', 'the', 'meal', 'all', 'together', '.'], 'aspect': ['meal', 'eggs'], 'position': [[3], [10]], 'sentiment': ['Neutral', 'Negative']}
# {'sentence': 'i rejected it because in the process of attempting to fix the eggs they broke something else in the dish and i was too frustrated to continue .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['i', 'rejected', 'it', 'because', 'in', 'the', 'process', 'of', 'attempting', 'to', 'fix', 'the', 'eggs', 'they', 'broke', 'something', 'else', 'in', 'the', 'dish', 'and', 'i', 'was', 'too', 'frustrated', 'to', 'continue', '.'], 'aspect': ['eggs', 'dish'], 'position': [[13], [20]], 'sentiment': ['Negative', 'Neutral']}
# {'sentence': 'to their credit they removed the dish from the check ; but no manager stopped by to ask what the problem was .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['to', 'their', 'credit', 'they', 'removed', 'the', 'dish', 'from', 'the', 'check', ';', 'but', 'no', 'manager', 'stopped', 'by', 'to', 'ask', 'what', 'the', 'problem', 'was', '.'], 'aspect': ['dish', 'manager'], 'position': [[7], [14]], 'sentiment': ['Neutral', 'Negative']}
# {'sentence': 'in the end our check came to $ 2 7 for 4 small pancakes , a breakfast burrito , an orange juice and an iced tea ( i had water ) .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'O', 'O', 'B-ASP', 'O', 'O'], 'tokens': ['in', 'the', 'end', 'our', 'check', 'came', 'to', '$', '2', '7', 'for', '4', 'small', 'pancakes', ',', 'a', 'breakfast', 'burrito', ',', 'an', 'orange', 'juice', 'and', 'an', 'iced', 'tea', '(', 'i', 'had', 'water', ')', '.'], 'aspect': ['pancakes', 'breakfast burrito', 'orange juice', 'iced tea', 'water'], 'position': [[14], [17, 18], [21, 22], [25, 26], [30]], 'sentiment': ['Negative', 'Neutral', 'Neutral', 'Neutral', 'Neutral']}
# {'sentence': 'much more than just a great view !', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['much', 'more', 'than', 'just', 'a', 'great', 'view', '!'], 'aspect': ['view'], 'position': [[7]], 'sentiment': ['Positive']}
# {'sentence': "– i am exceedingly pleased to report that my dinner at ray ' s boathouse last friday completely exceeded my expectations .", 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['–', 'i', 'am', 'exceedingly', 'pleased', 'to', 'report', 'that', 'my', 'dinner', 'at', 'ray', "'", 's', 'boathouse', 'last', 'friday', 'completely', 'exceeded', 'my', 'expectations', '.'], 'aspect': ['dinner'], 'position': [[10]], 'sentiment': ['Positive']}
# {'sentence': "ray ' s is something of a seattle institution , but given its gorgeous sound views , i had suspected that the accolades were more due to the scenery than to the food and service .", 'IOB': ['O', 'I-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'B-ASP', 'O', 'B-ASP', 'O'], 'tokens': ['ray', "'", 's', 'is', 'something', 'of', 'a', 'seattle', 'institution', ',', 'but', 'given', 'its', 'gorgeous', 'sound', 'views', ',', 'i', 'had', 'suspected', 'that', 'the', 'accolades', 'were', 'more', 'due', 'to', 'the', 'scenery', 'than', 'to', 'the', 'food', 'and', 'service', '.'], 'aspect': ["'", 'sound views', 'scenery', 'food', 'service'], 'position': [[2], [15, 16], [29], [33], [35]], 'sentiment': ['Positive', 'Positive', 'Neutral', 'Neutral', 'Negative']}
# {'sentence': "imagine my happy surprise upon finding that the views are only the third - best thing about ray ' s !", 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['imagine', 'my', 'happy', 'surprise', 'upon', 'finding', 'that', 'the', 'views', 'are', 'only', 'the', 'third', '-', 'best', 'thing', 'about', 'ray', "'", 's', '!'], 'aspect': ['views'], 'position': [[9]], 'sentiment': ['Positive']}
# {'sentence': 'to start things off , our lovely server brooke was quickly on hand to take my drink order .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O'], 'tokens': ['to', 'start', 'things', 'off', ',', 'our', 'lovely', 'server', 'brooke', 'was', 'quickly', 'on', 'hand', 'to', 'take', 'my', 'drink', 'order', '.'], 'aspect': ['server', 'drink'], 'position': [[8], [17]], 'sentiment': ['Positive', 'Neutral']}
# {'sentence': "my party of two was feeling particularly ambitious , and we splurged on the shilshole sampler . . . a beautiful assortment of enormous white gulf prawns , smoked albacore tuna , ray ' s fantastic manila clams seasoned with dill , scallops in a tasty soy dressing , and a tiny pile of dungeness crab atop a sublime butter sauce .", 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'I-ASP', 'I-ASP', 'I-ASP', 'O', 'B-ASP', 'I-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'I-ASP', 'I-ASP', 'I-ASP', 'O', 'B-ASP', 'I-ASP', 'I-ASP', 'O', 'I-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O'], 'tokens': ['my', 'party', 'of', 'two', 'was', 'feeling', 'particularly', 'ambitious', ',', 'and', 'we', 'splurged', 'on', 'the', 'shilshole', 'sampler', '.', '.', '.', 'a', 'beautiful', 'assortment', 'of', 'enormous', 'white', 'gulf', 'prawns', ',', 'smoked', 'albacore', 'tuna', ',', 'ray', "'", 's', 'fantastic', 'manila', 'clams', 'seasoned', 'with', 'dill', ',', 'scallops', 'in', 'a', 'tasty', 'soy', 'dressing', ',', 'and', 'a', 'tiny', 'pile', 'of', 'dungeness', 'crab', 'atop', 'a', 'sublime', 'butter', 'sauce', '.'], 'aspect': ['assortment of', 'white gulf prawns', 'smoked albacore tuna', 'manila clams seasoned with dill', 'scallops in a', 'soy dressing', 'dungeness crab', 'butter sauce'], 'position': [[22, 23], [25, 26, 27], [29, 30, 31], [37, 38, 39, 40, 41], [43, 44, 45], [47, 48], [55, 56], [60, 61]], 'sentiment': ['Positive', 'Positive', 'Positive', 'Positive', 'Neutral', 'Positive', 'Positive', 'Positive']}
# {'sentence': 'for my entr & eacute ; e , i completely enjoyed the seared alaskan sea scallops complemented by chard , artichoke hearts , fennel , and pecorino toscano .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'I-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['for', 'my', 'entr', '&', 'eacute', ';', 'e', ',', 'i', 'completely', 'enjoyed', 'the', 'seared', 'alaskan', 'sea', 'scallops', 'complemented', 'by', 'chard', ',', 'artichoke', 'hearts', ',', 'fennel', ',', 'and', 'pecorino', 'toscano', '.'], 'aspect': ['seared alaskan sea scallops', 'artichoke hearts', 'fennel'], 'position': [[13, 14, 15, 16], [21, 22], [24]], 'sentiment': ['Positive', 'Neutral', 'Neutral']}
# {'sentence': 'the scallops are apparently cooked in a black olive butter which really makes them unique ( not to mention tasty ) .', 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'I-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['the', 'scallops', 'are', 'apparently', 'cooked', 'in', 'a', 'black', 'olive', 'butter', 'which', 'really', 'makes', 'them', 'unique', '(', 'not', 'to', 'mention', 'tasty', ')', '.'], 'aspect': ['scallops', 'black olive butter'], 'position': [[2], [8, 9, 10]], 'sentiment': ['Positive', 'Neutral']}
# {'sentence': 'my friend enjoyed the grilled alaskan king salmon with delectable creamed washington russet potatoes and crisp green beans .', 'IOB': ['O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'I-ASP', 'I-ASP', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O'], 'tokens': ['my', 'friend', 'enjoyed', 'the', 'grilled', 'alaskan', 'king', 'salmon', 'with', 'delectable', 'creamed', 'washington', 'russet', 'potatoes', 'and', 'crisp', 'green', 'beans', '.'], 'aspect': ['grilled alaskan king salmon', 'creamed', 'green beans'], 'position': [[5, 6, 7, 8], [11], [17, 18]], 'sentiment': ['Positive', 'Positive', 'Positive']}
# {'sentence': 'i had a taste of all three items on her plate , and they were superb .', 'IOB': ['O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['i', 'had', 'a', 'taste', 'of', 'all', 'three', 'items', 'on', 'her', 'plate', ',', 'and', 'they', 'were', 'superb', '.'], 'aspect': ['taste', 'plate'], 'position': [[4], [11]], 'sentiment': ['Positive', 'Neutral']}
# {'sentence': "our server continued to be attentive throughout the night , but i did remain puzzled by one issue : who thinks that ray ' s is an appropriate place to take young children for dinner ?", 'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O'], 'tokens': ['our', 'server', 'continued', 'to', 'be', 'attentive', 'throughout', 'the', 'night', ',', 'but', 'i', 'did', 'remain', 'puzzled', 'by', 'one', 'issue', ':', 'who', 'thinks', 'that', 'ray', "'", 's', 'is', 'an', 'appropriate', 'place', 'to', 'take', 'young', 'children', 'for', 'dinner', '?'], 'aspect': ['server', 'dinner'], 'position': [[2], [35]], 'sentiment': ['Positive', 'Neutral']}
# {'sentence': "all considered , i have to say that ray ' s boathouse is deserving of its title as a seattle institution .", 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'I-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['all', 'considered', ',', 'i', 'have', 'to', 'say', 'that', 'ray', "'", 's', 'boathouse', 'is', 'deserving', 'of', 'its', 'title', 'as', 'a', 'seattle', 'institution', '.'], 'aspect': ['ray', 'boathouse'], 'position': [[9], [12]], 'sentiment': ['Positive', 'Positive']}
# {'sentence': 'while i could have done without the youth who shared the evening with us , our wonderful server and food made the experience a very positive one .', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['while', 'i', 'could', 'have', 'done', 'without', 'the', 'youth', 'who', 'shared', 'the', 'evening', 'with', 'us', ',', 'our', 'wonderful', 'server', 'and', 'food', 'made', 'the', 'experience', 'a', 'very', 'positive', 'one', '.'], 'aspect': ['server', 'food'], 'position': [[18], [20]], 'sentiment': ['Positive', 'Positive']}
# /usr/local/lib/python3.7/dist-packages/pyabsa/core/atepc/prediction/aspect_extractor.py:221: ResourceWarning: unclosed file <_io.TextIOWrapper name='/content/atepc_inference.result.json' mode='w' encoding='UTF-8'>
#   json.dump(json.JSONEncoder().encode({'results': results}), open(save_path, 'w'), ensure_ascii=False)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %% [markdown]
# # Train a model (FAST_LCF_ATEPC) for Aspect-based sentiment classification
# ## We dont run a training on Colab as it is too slow

# %%
import os

import findfile

from pyabsa.functional import ATEPCModelList
from pyabsa.functional import Trainer, ATEPCTrainer
from pyabsa.functional import ABSADatasetList
from pyabsa.functional import ATEPCConfigManager
from pyabsa.functional.dataset import DatasetItem

atepc_config = ATEPCConfigManager.get_atepc_config_english()

atepc_config.pretrained_bert = 'microsoft/deberta-v3-base'
atepc_config.model = ATEPCModelList.FAST_LCF_ATEPC
dataset_path = ABSADatasetList.Restaurant14
# or your local dataset: dataset_path = 'your local dataset path'

aspect_extractor = ATEPCTrainer(config=atepc_config,
                  dataset=dataset_path,
                  from_checkpoint='',  # set checkpoint to train on the checkpoint.
                  checkpoint_save_mode=1,
                  auto_device=True
                  ).load_trained_model()

# %% [markdown]
# # Train on your own dataset from a checkpoint

# %%
config = ATEPCConfigManager.get_atepc_config_english()

checkpoint_path = ATEPCCheckpointManager.get_checkpoint(checkpoint='english2')  # or
# checkpoint_path = 'lcfs_atepc_cdw_apcacc_86.17_apcf1_58.3_atef1_70.86'

config.model = ATEPCModelList.LCFS_ATEPC
config.evaluate_begin = 4
config.num_epoch = 5

TShirt = ABSADatasetList.TShirt
aspect_extractor = Trainer(config=config,
              dataset=TShirt,
              from_checkpoint=checkpoint_path,
              checkpoint_save_mode=1,
              auto_device=True
              ).load_trained_model()

# %% [markdown]
# # Deployment Example

# %%
# -*- coding: utf-8 -*-
# file: deploy_demo.py
# time: 2021/10/10
# author: yangheng <hy345@exeter.ac.uk>
# github: https://github.com/yangheng95
# Copyright (C) 2021. All Rights Reserved.

import gradio as gr
import pandas as pd

from pyabsa import ATEPCCheckpointManager

aspect_extractor = ATEPCCheckpointManager.get_aspect_extractor(checkpoint='multilingual2',
                                                               auto_device=True  # False means load model on CPU
                                                               )


def inference(text):
    result = aspect_extractor.extract_aspect(inference_source=[text],
                                             pred_sentiment=True)

    result = pd.DataFrame({
        'aspect': result[0]['aspect'],
        'sentiment': result[0]['sentiment']
    })

    return result


if __name__ == '__main__':
    iface = gr.Interface(
        fn=inference,
        inputs=["text"],
        examples=[['The wine list is incredible and extensive and diverse , the food is all incredible and the staff was all very nice ,'
                   ' good at their jobs and cultured .'],
                  ['Though the menu includes some unorthodox offerings (a peanut butter roll, for instance), the classics are pure and '
                   'great--we have never had better sushi anywhere, including Japan.'],
                  ['Everything, from the soft bread, soggy salad, and 50 minute wait time, with an incredibly rude service to deliver'
                   ' below average food .'],
                  ['Even though it is running Snow Leopard, 2.4 GHz C2D is a bit of an antiquated CPU and thus the occasional spinning '
                   'wheel would appear when running Office Mac applications such as Word or Excel .'],
                  ['This demo is trained on the laptop and restaurant and other review datasets from ABSADatasets (https://github.com/yangheng95/ABSADatasets)'],
                  ['To fit on your data, please train the model on your own data, see the PyABSA (https://github.com/yangheng95/PyABSA)'],
                  ],
        outputs="dataframe",
        title='Aspect Term Extraction for Short Texts (powered by PyABSA)'
    )

    iface.launch()
