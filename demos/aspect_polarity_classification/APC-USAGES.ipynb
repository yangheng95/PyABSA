# %% [markdown]
# # Aspect-based sentiment classification via [PyABSA](https://github.com/yangheng95/PyABSA)
# More usages see [here](https://github.com/yangheng95/PyABSA/tree/release/demos/aspect_polarity_classification)

# %%
# !pip install pyabsa
# Out:
# Collecting pyabsa
#   Downloading pyabsa-1.10.1-py3-none-any.whl (207 kB)
#      |████████████████████████████████| 207 kB 3.6 MB/s
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 1.5 MB/s
# Collecting autocuda>=0.9
#   Downloading autocuda-0.11-py3-none-any.whl (4.8 kB)
# Collecting pytorch-warmup
#   Downloading pytorch-warmup-0.1.0.tar.gz (314 kB)
#      |████████████████████████████████| 314 kB 46.0 MB/s
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (from pyabsa) (2.2.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from pyabsa) (4.1.1)
# Collecting transformers>4.5
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 24.5 MB/s
# Collecting update-checker
#   Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: torch<1.11.0,>1.0.0 in /usr/local/lib/python3.7/dist-packages (from pyabsa) (1.10.0+cu111)
# Collecting gitpython
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 22.6 MB/s
# Requirement already satisfied: gdown>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from pyabsa) (4.4.0)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 69.7 MB/s
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from pyabsa) (2.6.3)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from pyabsa) (1.1.0)
# Collecting findfile>=1.7.3
#   Downloading findfile-1.7.7-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pyabsa) (4.64.0)
# Collecting metric-visualizer>=0.4.16
#   Downloading metric_visualizer-0.4.17-py3-none-any.whl (10 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown>=4.4.0->pyabsa) (3.6.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from gdown>=4.4.0->pyabsa) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown>=4.4.0->pyabsa) (1.15.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown>=4.4.0->pyabsa) (4.6.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from metric-visualizer>=0.4.16->pyabsa) (3.2.2)
# Collecting tikzplotlib
#   Downloading tikzplotlib-0.10.1-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.1 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from metric-visualizer>=0.4.16->pyabsa) (1.4.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from metric-visualizer>=0.4.16->pyabsa) (0.8.9)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 4.9 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers>4.5->pyabsa) (1.21.5)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers>4.5->pyabsa) (4.11.3)
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 56.6 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 32.7 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers>4.5->pyabsa) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>4.5->pyabsa) (2019.12.20)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 56.3 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers>4.5->pyabsa) (3.0.8)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.3 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers>4.5->pyabsa) (3.8.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->metric-visualizer>=0.4.16->pyabsa) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->metric-visualizer>=0.4.16->pyabsa) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->metric-visualizer>=0.4.16->pyabsa) (1.4.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown>=4.4.0->pyabsa) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown>=4.4.0->pyabsa) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown>=4.4.0->pyabsa) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown>=4.4.0->pyabsa) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown>=4.4.0->pyabsa) (1.7.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>4.5->pyabsa) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>4.5->pyabsa) (1.1.0)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval->pyabsa) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->pyabsa) (3.1.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy->pyabsa) (2.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy->pyabsa) (1.0.6)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy->pyabsa) (0.4.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy->pyabsa) (1.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy->pyabsa) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy->pyabsa) (57.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy->pyabsa) (3.0.6)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy->pyabsa) (7.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy->pyabsa) (0.9.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy->pyabsa) (1.1.3)
# Collecting webcolors
#   Downloading webcolors-1.11.1-py3-none-any.whl (9.9 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from tikzplotlib->metric-visualizer>=0.4.16->pyabsa) (7.1.2)
# Building wheels for collected packages: pytorch-warmup, seqeval
#   Building wheel for pytorch-warmup (setup.py) ... done
#   Created wheel for pytorch-warmup: filename=pytorch_warmup-0.1.0-py3-none-any.whl size=5802 sha256=8d61effa5079a672e687e5c008f53412ef2d679fdb304ec2f32958db386dfca8
#   Stored in directory: /root/.cache/pip/wheels/c7/5d/24/9475e442daa1e9332c122c79fb5131b9e4e91946009365902e
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=14c2a16a076e10432b4159151eea4604388de95a0fd42ea60cda2efe0909a03f
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built pytorch-warmup seqeval
# Installing collected packages: webcolors, smmap, pyyaml, tokenizers, tikzplotlib, sacremoses, huggingface-hub, gitdb, findfile, update-checker, transformers, seqeval, sentencepiece, pytorch-warmup, metric-visualizer, gitpython, autocuda, pyabsa
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed autocuda-0.11 findfile-1.7.7 gitdb-4.0.9 gitpython-3.1.27 huggingface-hub-0.5.1 metric-visualizer-0.4.17 pyabsa-1.10.1 pytorch-warmup-0.1.0 pyyaml-6.0 sacremoses-0.0.49 sentencepiece-0.1.96 seqeval-1.2.2 smmap-5.0.0 tikzplotlib-0.10.1 tokenizers-0.12.1 transformers-4.18.0 update-checker-0.18.0 webcolors-1.11.1

# %% [markdown]
# ## Find Available Checkpoints For **Current Version**

# %%
from pyabsa import available_checkpoints
checkpoint_map = available_checkpoints(from_local=False)
# Out:
# This script could only be used to manage NVIDIA GPUs,but no GPU found in your device
# Remote ABSADataset version: 2022.03.22 Local ABSADatasets version: N.A.
# Unknown local version for ABSADatasets, please check the latest version of ABSADatasets at https://github.com/yangheng95/ABSADatasets
# Downloading...
# From: https://drive.google.com/uc?id=1CBVGPA3xdQqdkFFwzO5T2Q4reFtzFIJZ
# To: /content/checkpoints.json
# 100%|██████████| 6.39k/6.39k [00:00<00:00, 1.79MB/s]
# ********** Available APC model checkpoints for Version:1.10.1 (this version) **********
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/1B0RHazOCm2eOWLWExQkeapHr9d3OiZl7/view?usp=sharing
# Training Model: FAST-LCF-MDeBERTa
# Training Dataset: Chinese
# Description: Trained on RTX3090
# Available Version: 1.8.2+
# Checkpoint File: fast_lcf_bert_Chinese_acc_97.11_f1_96.54.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/15ls1hcGvk27UnfMsXZtk780h7tTBbNws/view?usp=sharing
# Training Model: FAST-LCF-Deberta
# Training Dataset: Multilingual
# Description: Trained on RTX3090
# Available Version: 1.8.2+
# Checkpoint File: fast_lcf_bert_Multilingual_acc_94.72_f1_90.07.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id:
# Description: You can help us by sharing checkpoints (e.g. models trained on you own datasets) with community.
# Checkpoint File: PLEASE NOTE THAT THIS IS NOT A REAL CHECKPOINT!
# Available Version:
# ----------------------------------------------------------------------------------------------------
# ********** Available ATEPC model checkpoints for Version:1.10.1 (this version) **********
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/1HjJm80Ed5LLVYCLldRl_r9a_VJ_E9AcQ/view?usp=sharing
# Training Model: FAST-LCF-ATEPC
# Training Dataset: English
# Description: Trained on RTX3090
# Available Version: 1.8.4+
# Checkpoint File: fast_lcf_atepc_English_cdw_apcacc_80.16_apcf1_78.34_atef1_75.39.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/1GvfHAWVJeEKXoy2-bPtourWEniCfwwv0/view?usp=sharing
# Training Model: FAST-LCF-ATEPC
# Training Dataset: English
# Description: Trained on RTX3090
# Available Version: 1.8.4+
# Checkpoint File: fast_lcf_atepc_English_cdw_apcacc_82.93_apcf1_80.7_atef1_78.77.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/1X9-IulQuk1MBNfoHoi_RIW8e3qUgeyH2/view?usp=sharing
# Training Model: FAST-LCFS-ATEPC
# Training Dataset: English
# Description: Trained on RTX3090, this checkpoint use bert-spc in ATEPC training
# Available Version: 1.8.4+
# Checkpoint File: fast_lcfs_atepc_English_cdw_apcacc_85.03_apcf1_82.36_atef1_84.48.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/1SzzUkuMJLjfxGZmInqmBQi5U2ZxTeG2L/view?usp=sharing
# Training Model: FAST-LCF-DeBERTa
# Training Dataset: Chinese
# Description: Trained on RTX3090
# Available Version: 1.8.4+
# Checkpoint File: fast_lcf_atepc_Chinese_cdw_apcacc_96.69_apcf1_96.25_atef1_92.26.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/155itPM5hz037ytvqu6XuMArbxy3B2Vr8/view?usp=sharing
# Training Model: FAST-LCF-ATEPC
# Training Dataset: ABSADatasets.Multilingual
# Description: Trained on RTX3090
# Available Version: 1.8.4+
# Checkpoint File: fast_lcf_atepc_Multilingual_cdw_apcacc_79.61_apcf1_76.24_atef1_63.29.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/1LAC-AJfCf50r_7dtDzj73kn02Mr5g2ky/view?usp=sharing
# Training Model: FAST-LCF-ATEPC
# Training Dataset: ABSADatasets.Multilingual
# Description: Trained on RTX3090
# Available Version: 1.8.4+
# Checkpoint File: fast_lcf_atepc_Multilingual_cdw_apcacc_86.37_apcf1_82.94_atef1_84.78.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id:
# Description: You can help us by sharing checkpoints (e.g. models trained on you own datasets) with community.
# Checkpoint File: PLEASE NOTE THAT THIS IS NOT A REAL CHECKPOINT!
# Available Version:
# ----------------------------------------------------------------------------------------------------
# ********** Available TC model checkpoints for Version:1.10.1 (this version) **********
# ----------------------------------------------------------------------------------------------------
# id:
# Description: You can help us by sharing checkpoints (e.g. models trained on you own datasets) with community.
# Checkpoint File: PLEASE NOTE THAT THIS IS NOT A REAL CHECKPOINT!
# Available Version:
# ----------------------------------------------------------------------------------------------------
# There may be some checkpoints available for early versions of PyABSA, see ./checkpoints.json
# /usr/local/lib/python3.7/dist-packages/pyabsa/functional/checkpoint/checkpoint_manager.py:269: ResourceWarning: unclosed file <_io.TextIOWrapper name='./checkpoints.json' mode='r' encoding='UTF-8'>
#   checkpoint_map = json.load(open('./checkpoints.json', 'r'))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %% [markdown]
# # Init a sentiment classifier from online checkpoint or local checkpoint

# %%
from pyabsa import APCCheckpointManager, ABSADatasetList
sent_classifier = APCCheckpointManager.get_sentiment_classifier(checkpoint='multilingual',
                                   auto_device=True,  # Use CUDA if available
                                   )
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1CBVGPA3xdQqdkFFwzO5T2Q4reFtzFIJZ
# To: /content/checkpoints.json
# 100%|██████████| 6.39k/6.39k [00:00<00:00, 7.96MB/s]
# /usr/local/lib/python3.7/dist-packages/pyabsa/functional/checkpoint/checkpoint_manager.py:269: ResourceWarning: unclosed file <_io.TextIOWrapper name='./checkpoints.json' mode='r' encoding='UTF-8'>
#   checkpoint_map = json.load(open('./checkpoints.json', 'r'))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# ********** Available APC model checkpoints for Version:1.10.1 (this version) **********
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/1B0RHazOCm2eOWLWExQkeapHr9d3OiZl7/view?usp=sharing
# Training Model: FAST-LCF-MDeBERTa
# Training Dataset: Chinese
# Description: Trained on RTX3090
# Available Version: 1.8.2+
# Checkpoint File: fast_lcf_bert_Chinese_acc_97.11_f1_96.54.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id: https://drive.google.com/file/d/15ls1hcGvk27UnfMsXZtk780h7tTBbNws/view?usp=sharing
# Training Model: FAST-LCF-Deberta
# Training Dataset: Multilingual
# Description: Trained on RTX3090
# Available Version: 1.8.2+
# Checkpoint File: fast_lcf_bert_Multilingual_acc_94.72_f1_90.07.zip
# Author: H, Yang (yangheng@m.scnu.edu.cn)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# id:
# Description: You can help us by sharing checkpoints (e.g. models trained on you own datasets) with community.
# Checkpoint File: PLEASE NOTE THAT THIS IS NOT A REAL CHECKPOINT!
# Available Version:
# ----------------------------------------------------------------------------------------------------
# There may be some checkpoints available for early versions of PyABSA, see ./checkpoints.json
# Downloading checkpoint:multilingual from Google Drive...
# Notice: The pretrained model are used for testing, neither trained using fine-tuned hyper-parameters nor trained with enough steps, it is recommended to train the model on your own custom datasets
# Downloading...
# From: https://drive.google.com/uc?id=15ls1hcGvk27UnfMsXZtk780h7tTBbNws
# To: /content/checkpoints/APC_MULTILINGUAL_CHECKPOINT/any_model.zip
# 100%|██████████| 898M/898M [00:09<00:00, 97.9MB/s]
# Find zipped checkpoint: ./checkpoints/APC_MULTILINGUAL_CHECKPOINT/any_model.zip, unzipping...
# Done.
# Google Drive applies a restriction on public large file downloading, if you find the checkpoint downloaded is None or small, please download it via browser: 15ls1hcGvk27UnfMsXZtk780h7tTBbNws
# Load sentiment classifier from ./checkpoints/APC_MULTILINGUAL_CHECKPOINT
# config: ./checkpoints/APC_MULTILINGUAL_CHECKPOINT/any_model/fast_lcf_bert_Multilingual_acc_94.72_f1_90.07/fast_lcf_bert.config
# state_dict: ./checkpoints/APC_MULTILINGUAL_CHECKPOINT/any_model/fast_lcf_bert_Multilingual_acc_94.72_f1_90.07/fast_lcf_bert.state_dict
# model: None
# tokenizer: ./checkpoints/APC_MULTILINGUAL_CHECKPOINT/any_model/fast_lcf_bert_Multilingual_acc_94.72_f1_90.07/fast_lcf_bert.tokenizer
# /usr/local/lib/python3.7/dist-packages/pyabsa/core/apc/prediction/sentiment_classifier.py:64: ResourceWarning: unclosed file <_io.BufferedReader name='./checkpoints/APC_MULTILINGUAL_CHECKPOINT/any_model/fast_lcf_bert_Multilingual_acc_94.72_f1_90.07/fast_lcf_bert.config'>
#   self.opt = pickle.load(open(config_path, mode='rb'))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# Downloading:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/579 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.11M [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Downloading:   0%|          | 0.00/534M [00:00<?, ?B/s]
# Some weights of the model checkpoint at microsoft/mdeberta-v3-base were not used when initializing DebertaV2Model: ['lm_predictions.lm_head.bias', 'lm_predictions.lm_head.LayerNorm.bias', 'mask_predictions.dense.bias', 'lm_predictions.lm_head.LayerNorm.weight', 'mask_predictions.classifier.weight', 'mask_predictions.LayerNorm.weight', 'lm_predictions.lm_head.dense.bias', 'mask_predictions.dense.weight', 'mask_predictions.LayerNorm.bias', 'mask_predictions.classifier.bias', 'lm_predictions.lm_head.dense.weight']
# - This IS expected if you are initializing DebertaV2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaV2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /usr/local/lib/python3.7/dist-packages/pyabsa/core/apc/models/ensembler.py:135: ResourceWarning: unclosed file <_io.BufferedWriter name='fast_lcf_bert.Multilingual.dataset.533554b5619a526aa1a9eb1b1f30aae05097da4b94e805c296c2477ba59dc075.cache'>
#   pickle.dump((self.train_set, self.valid_set, self.test_set, self.opt), open(cache_path, mode='wb'))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# Caching dataset... please remove cached dataset if change model or dataset
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /usr/local/lib/python3.7/dist-packages/catalogue.py:138: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for entry_point in AVAILABLE_ENTRY_POINTS.get(self.entry_point_namespace, []):
# Config used in Training:
# ABSADatasetsVersion:2021.12.06	-->	Calling Count:0
# PyABSAVersion:1.8.2	-->	Calling Count:0
# SRD:3	-->	Calling Count:0
# auto_device:True	-->	Calling Count:4116
# batch_size:16	-->	Calling Count:6
# cache_dataset:True	-->	Calling Count:2
# cross_validate_fold:-1	-->	Calling Count:2
# dataset_file:{'train': ['integrated_datasets/apc_datasets/SemEval/laptop14/Laptops_Train.xml.seg', 'integrated_datasets/apc_datasets/SemEval/restaurant16/restaurant_train.raw', 'integrated_datasets/apc_datasets/SemEval/restaurant16/restaurant_train.raw.augment', 'integrated_datasets/apc_datasets/ACL_Twitter/acl-14-short-data/train.raw', 'integrated_datasets/apc_datasets/MAMS/train.xml.dat', 'integrated_datasets/apc_datasets/Television/Television_Train.xml.seg', 'integrated_datasets/apc_datasets/TShirt/Menstshirt_Train.xml.seg', 'integrated_datasets/apc_datasets/Yelp/yelp.train.txt', 'integrated_datasets/apc_datasets/Chinese/phone/phone.train.txt', 'integrated_datasets/apc_datasets/Chinese/camera/camera.train.txt', 'integrated_datasets/apc_datasets/Chinese/notebook/notebook.train.txt', 'integrated_datasets/apc_datasets/Chinese/car/car.train.txt'], 'test': ['integrated_datasets/apc_datasets/SemEval/laptop14/Laptops_Test_Gold.xml.seg', 'integrated_datasets/apc_datasets/SemEval/restaurant16/restaurant_test.raw', 'integrated_datasets/apc_datasets/ACL_Twitter/acl-14-short-data/test.raw', 'integrated_datasets/apc_datasets/MAMS/test.xml.dat', 'integrated_datasets/apc_datasets/Television/Television_Test_Gold.xml.seg', 'integrated_datasets/apc_datasets/TShirt/Menstshirt_Test_Gold.xml.seg', 'integrated_datasets/apc_datasets/Yelp/yelp.test.txt', 'integrated_datasets/apc_datasets/Chinese/phone/phone.test.txt', 'integrated_datasets/apc_datasets/Chinese/camera/camera.test.txt', 'integrated_datasets/apc_datasets/Chinese/notebook/notebook.test.txt', 'integrated_datasets/apc_datasets/Chinese/car/car.test.txt'], 'valid': ['integrated_datasets/apc_datasets/SemEval/laptop14/Laptops_Valid_Gold.xml.seg', 'integrated_datasets/apc_datasets/SemEval/restaurant16/restaurant_valid.raw', 'integrated_datasets/apc_datasets/MAMS/valid.xml.dat']}	-->	Calling Count:4115
# dataset_item:['Laptop14', 'Restaurant16', 'ACL_Twitter', 'MAMS', 'Television', 'TShirt', 'Yelp', 'Phone', 'Camera', 'Notebook', 'Car']	-->	Calling Count:0
# dataset_name:Multilingual	-->	Calling Count:4
# dca_layer:3	-->	Calling Count:0
# dca_p:1	-->	Calling Count:0
# deep_ensemble:False	-->	Calling Count:0
# device:cuda:0	-->	Calling Count:17955
# device_name:NVIDIA GeForce RTX 3090	-->	Calling Count:0
# dlcf_a:2	-->	Calling Count:0
# dropout:0.5	-->	Calling Count:2
# dynamic_truncate:True	-->	Calling Count:0
# embed_dim:768	-->	Calling Count:6
# ensemble_mode:cat	-->	Calling Count:0
# eta:-1	-->	Calling Count:0
# evaluate_begin:5	-->	Calling Count:1644
# hidden_dim:768	-->	Calling Count:0
# index_to_label:{0: 'Negative', 1: 'Neutral', 2: 'Positive'}	-->	Calling Count:0
# initializer:xavier_uniform_	-->	Calling Count:1
# inputs_cols:['lcf_vec', 'text_bert_indices', 'text_raw_bert_indices']	-->	Calling Count:4492
# l2reg:1e-06	-->	Calling Count:1
# label_to_index:{'Negative': 0, 'Neutral': 1, 'Positive': 2}	-->	Calling Count:0
# lcf:cdw	-->	Calling Count:0
# learning_rate:2e-05	-->	Calling Count:1
# log_step:5	-->	Calling Count:4117
# max_seq_len:80	-->	Calling Count:8974
# max_test_metrics:{'max_apc_test_acc': 0.9471913891691893, 'max_apc_test_f1': 0.9006938075375056, 'max_ate_test_f1': 0}	-->	Calling Count:8
# metrics_of_this_checkpoint:{'acc': 0.9471913891691893, 'f1': 0.9006938075375056}	-->	Calling Count:4
# model:<class 'pyabsa.core.apc.models.fast_lcf_bert.FAST_LCF_BERT'>	-->	Calling Count:7
# model_name:fast_lcf_bert	-->	Calling Count:11
# model_path_to_save:checkpoints	-->	Calling Count:6
# num_epoch:10	-->	Calling Count:2
# optimizer:adam	-->	Calling Count:1
# patience:16407335.924999999	-->	Calling Count:4
# polarities_dim:3	-->	Calling Count:6
# pretrained_bert:microsoft/mdeberta-v3-base	-->	Calling Count:8
# save_mode:1	-->	Calling Count:3
# seed:52	-->	Calling Count:7
# sigma:0.3	-->	Calling Count:0
# similarity_threshold:1	-->	Calling Count:0
# srd_alignment:True	-->	Calling Count:0
# use_bert_spc:True	-->	Calling Count:4487
# use_syntax_based_SRD:False	-->	Calling Count:0
# window:lr	-->	Calling Count:0

# %% [markdown]
# # Aspect Sentiment Inference

# %%
examples = [
    'The [ASP]battery-life[ASP], and this [ASP]battery[ASP] is ok',
    'The [ASP] battery-life [ASP] is bad',
    'The [ASP] battery-life [ASP] is good',
    'The [ASP] battery-life [ASP] ',
    'Strong build though which really adds to its [ASP]durability[ASP] .',  # !sent! Positive
    'Strong [ASP]build[ASP] though which really adds to its durability . !sent! Positive',
    'The [ASP]battery life[ASP] is excellent - 6-7 hours without charging . !sent! Positive',
    'I have had my computer for 2 weeks already and it [ASP]works[ASP] perfectly . !sent! Positive',
    'And I may be the only one but I am really liking [ASP]Windows 8[ASP] . !sent! Positive',
]

for ex in examples:
    result = sent_classifier.infer(ex, print_result=True)
# Out:
# The [ASP]battery-life[ASP], and this [ASP]battery[ASP] is ok  -> No the reference sentiment found
# 100%|██████████| 2/2 [00:00<00:00, 740.19it/s, building word indices...]
# /usr/local/lib/python3.7/dist-packages/transformers/models/deberta_v2/modeling_deberta_v2.py:538: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   bucket_pos = np.where(abs_pos <= mid, relative_pos, log_pos * sign).astype(np.int)
# The battery -> 0.982(confidence:Positive)-life -> 0.981(confidence:Positive) , and this battery -> 0.982(confidence:Positive) is ok
# The [ASP] battery-life [ASP] is bad  -> No the reference sentiment found
# The  battery-life  -> 0.921(confidence:Negative) is bad
# The [ASP] battery-life [ASP] is good  -> No the reference sentiment found
# The  battery-life  -> 0.998(confidence:Positive) is good
# The [ASP] battery-life [ASP]   -> No the reference sentiment found
# The  battery-life  -> 0.868(confidence:Positive)
# Strong build though which really adds to its [ASP]durability[ASP] .  -> No the reference sentiment found
# Strong build though which really adds to its durability -> 0.997(confidence:Positive) .
#  Strong build -> Positive(confidence:0.997, ref:Positive) though which really adds to its durability .
#  The battery life -> Positive(confidence:0.998, ref:Positive) is excellent - 6-7 hours without charging .
#  I have had my computer for 2 weeks already and it works -> Positive(confidence:0.998, ref:Positive) perfectly .
#  And I may be the only one but I am really liking Windows 8 -> Positive(confidence:0.998, ref:Positive) .

# %% [markdown]
# # Batch Sentiment Inference

# %%
inference_sets = ABSADatasetList.Phone
results = sent_classifier.batch_infer(target_file=inference_sets,
                     print_result=True,
                     save_result=True,
                     ignore_error=False,
                     )
# Out:
# Loading Phone dataset from:  https://github.com/yangheng95/ABSADatasets
# Clone ABSADatasets from https://github.com/yangheng95/ABSADatasets.git
# loading: integrated_datasets/apc_datasets/102.Chinese/107.phone/phone.test.txt.inference
# 高 [ASP]分 辨 率[ASP] 决 定 了 其 拥 有 比 以 往 采 用 [ASP]分 辨 率[ASP] 的 娱 乐 机 型 更 精 细 逼 真 的 画 面 效 果 !sent! Positive
#   -> Unequal length of reference sentiment and aspects, ignore the reference sentiment.
# 和 弦 [ASP]铃 声[ASP] 且 [ASP]铃 声[ASP] 雄 厚 有 力 !sent! Positive
#   -> Unequal length of reference sentiment and aspects, ignore the reference sentiment.
# 具 体 表 现 在 接 电 话 一 方 听 到 说 话 方 周 围 [ASP]噪 音[ASP] 过 大 且 [ASP]噪 音[ASP] 和 通 话 声 音 在 一 个 层 面 上 !sent! Negative
#   -> Unequal length of reference sentiment and aspects, ignore the reference sentiment.
# 随 机 配 的 [ASP]播 放 器[ASP] 感 觉 比 里 的 [ASP]播 放 器[ASP] 好 一 些 !sent! Positive
#   -> Unequal length of reference sentiment and aspects, ignore the reference sentiment.
#  26%|██▌       | 168/657 [00:00<00:00, 1679.52it/s, building word indices...]
# AspectTooLongWarning -> <aspect: 磨 沙 的 外 壳 不 易 留 下 指 纹> is too long, <text:   磨 沙 的 外 壳 不 易 留 下 指 纹   >, <polarity: Positive>
# 100%|██████████| 657/657 [00:00<00:00, 1722.17it/s, building word indices...]
# /usr/local/lib/python3.7/dist-packages/transformers/models/deberta_v2/modeling_deberta_v2.py:538: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   bucket_pos = np.where(abs_pos <= mid, relative_pos, log_pos * sign).astype(np.int)
#  精 妙 独 特 的 外 形 设 计 -> Positive(confidence:0.999, ref:Positive)
#  可 旋 转 的 双 面 设 计 -> Positive(confidence:0.999, ref:Positive) 很 有 味 道
#  完 美 的 音 乐 表 现 -> Positive(confidence:0.998, ref:Positive)
#  达 到 最 佳 音 乐 播 放 效 果 -> Positive(confidence:0.999, ref:Positive)
#  丰 富 的 按 键 设 计 -> Positive(confidence:0.998, ref:Positive)
#  强 大 的 功 能 扩 展 性 -> Positive(confidence:0.999, ref:Positive)
#  差 强 人 意 的 屏 幕 显 示 效 果 -> Negative(confidence:0.98, ref:Negative)
#  导 致 屏 幕 视 觉 效 果 -> Negative(confidence:0.995, ref:Negative) 不 佳
#  较 长 的 充 电 完 成 时 间 -> Positive(confidence:0.966, ref:Negative)
#  光 线 好 时 照 相 效 果 -> Positive(confidence:0.998, ref:Positive) 还 可 以
#  诺 的 按 键 间 缝 隙 -> Negative(confidence:0.556, ref:Negative) 大
#  被 她 迷 人 漂 亮 外 观 -> Positive(confidence:0.999, ref:Positive) 和 蓝 牙 功 能 所 吸 引
#  外 形 -> Positive(confidence:0.998, ref:Positive) 佳
#  手 感 -> Positive(confidence:0.998, ref:Positive) 好
#  一 个 最 突 出 我 不 太 能 接 受 的 就 是 屏 幕 反 应 -> Negative(confidence:0.996, ref:Negative) 比 较 慢
#  通 讯 录 -> Negative(confidence:0.993, ref:Negative) 查 找 没 有 我 以 前 的 诺 基 亚 的 好 用
#  并 且 外 壳 -> Positive(confidence:0.571, ref:Negative) 好 像 很 容 易 磨 损
#  整 个 造 型 -> Positive(confidence:0.999, ref:Positive) 简 洁 而 又 不 失 华 美
#  效 果 -> Positive(confidence:0.998, ref:Positive) 非 常 好
#  但 在 低 音 方 面 -> Negative(confidence:0.996, ref:Negative) 表 现 得 差 强 人 意
#  的 照 相 功 能 -> Positive(confidence:0.999, ref:Positive) 比 较 全 面
#  还 可 以 使 用 导 航 键 -> Positive(confidence:0.999, ref:Positive) 很 方 便 的 调 节 取 景 亮 度
#  待 机 时 间 -> Positive(confidence:0.996, ref:Positive) 长
#  软 件 设 计 -> Positive(confidence:0.997, ref:Positive) 较 为 人 性 化
#  软 件 反 映 速 度 -> Positive(confidence:0.998, ref:Positive) 较 快
#  同 时 在 数 据 传 输 上 使 用 了 简 易 方 便 的 红 外 接 口 -> Positive(confidence:0.999, ref:Positive)
#  屏 幕 分 辨 率 -> Negative(confidence:0.996, ref:Negative) 较 低
#  所 以 在 显 示 效 果 -> Negative(confidence:0.996, ref:Negative) 上 略 显 惨 淡
#  随 机 所 送 配 件 -> Negative(confidence:0.996, ref:Negative) 太 少
#  电 话 本 -> Negative(confidence:0.986, ref:Negative) 查 询 麻 烦
#  但 在 实 际 使 用 中 按 键 的 使 用 -> Negative(confidence:0.997, ref:Negative) 有 些 生 硬
#  屏 幕 -> Positive(confidence:0.998, ref:Positive) 是 多 普 达 的 一 大 亮 点
#  它 在 屏 幕 尺 寸 -> Positive(confidence:0.991, ref:Negative) 上 并 不 占 什 么 优 势
#  但 显 示 效 果 -> Positive(confidence:0.999, ref:Positive) 却 绝 对 不 逊 色 于 它 们
#  整 个 屏 幕 的 背 光 -> Positive(confidence:0.999, ref:Positive) 非 常 均 匀
#  而 且 由 于 屏 幕 的 尺 寸 -> Negative(confidence:0.975, ref:Negative) 小
#  不 过 由 于 屏 幕 的 分 辨 率 -> Positive(confidence:0.998, ref:Positive) 很 高
#  屏 幕 能 够 显 示 的 行 数 -> Positive(confidence:0.998, ref:Positive) 也 很 多
#  信 息 量 -> Positive(confidence:0.998, ref:Positive) 很 大
#  外 观 -> Positive(confidence:0.998, ref:Positive) 很 亮 丽
#  机 身 -> Positive(confidence:0.855, ref:Positive) 虽 说 不 是 最 薄 的
#  按 键 的 设 计 -> Positive(confidence:0.998, ref:Positive) 很 合 理
#  但 每 个 键 的 尺 寸 -> Positive(confidence:0.66, ref:Positive) 都 很 大
#  它 的 键 盘 背 景 灯 -> Positive(confidence:0.999, ref:Positive) 也 很 有 特 色
#  音 频 播 放 -> Positive(confidence:0.998, ref:Positive) 我 认 为 应 该 可 以 算 是 它 的 最 大 优 点 了
#  音 响 效 果 -> Positive(confidence:0.998, ref:Positive) 也 很 好
#  立 体 感 -> Positive(confidence:0.998, ref:Positive) 特 别 强
#  界 面 -> Positive(confidence:0.998, ref:Positive) 简 单
#  效 果 -> Positive(confidence:0.998, ref:Positive) 都 很 好
#  待 机 时 间 -> Positive(confidence:0.996, ref:Positive) 长
#  摄 像 头 的 效 果 -> Negative(confidence:0.992, ref:Negative) 不 好
#  不 仅 噪 点 -> Positive(confidence:0.805, ref:Negative) 把 握 的 不 好
#  反 应 延 迟 现 象 -> Negative(confidence:0.99, ref:Negative) 就 显 得 比 较 突 出 了
#  开 机 速 度 -> Negative(confidence:0.993, ref:Negative) 慢
#  但 耐 磨 性 -> Negative(confidence:0.985, ref:Negative) 就 差 多 了
#  声 音 -> Negative(confidence:0.994, ref:Negative) 太 小
#  震 动 -> Negative(confidence:0.994, ref:Negative) 也 太 软
#  估 计 可 能 是 手 机 顶 端 的 发 声 孔 -> Negative(confidence:0.995, ref:Negative) 太 小 所 致
#  铃 声 的 音 量 -> Negative(confidence:0.995, ref:Negative) 很 小
#  另 外 听 筒 的 音 量 -> Negative(confidence:0.992, ref:Negative) 也 不 大
#  诺 基 亚 是 一 款 综 合 素 质 比 较 出 众 的 音 乐 机 型 -> Positive(confidence:0.999, ref:Positive)
#  尤 其 是 强 大 的 多 媒 体 娱 乐 功 能 -> Positive(confidence:0.998, ref:Positive) 给 我 留 下 了 深 刻 的 印 象
#  由 于 巧 妙 的 外 形 造 型 -> Positive(confidence:0.999, ref:Positive) 使 得 给 人 的 整 体 印 象 依 然 十 分 小 巧
#  屏 幕 效 果 方 面 -> Positive(confidence:0.999, ref:Positive) 都 比 较 令 人 满 意
#  给 用 户 带 来 了 很 好 的 操 作 方 式 -> Positive(confidence:0.999, ref:Positive)
#  仅 运 行 内 存 性 能 -> Negative(confidence:0.992, ref:Negative) 表 现 不 会 太 强 虽 然 采 用 了 全 新 的 架 构
#  不 过 的 速 度 表 现 -> Negative(confidence:0.996, ref:Negative) 也 不 好
#  屏 幕 表 现 力 -> Negative(confidence:0.996, ref:Negative) 依 旧 不 足 采 用 的 依 旧 是 传 统 的 的 屏 幕 分 辨 率
#  手 持 使 用 的 手 感 -> Positive(confidence:0.998, ref:Positive) 较 好
#  用 手 写 时 速 度 -> Positive(confidence:0.998, ref:Positive) 时 比 较 快
#  而 且 中 文 识 别 率 -> Positive(confidence:0.998, ref:Positive) 很 高
#  质 量 -> Positive(confidence:0.998, ref:Positive) 很 好
#  使 用 期 间 机 器 反 映 速 度 -> Positive(confidence:0.998, ref:Positive) 较 快
#  而 且 手 机 的 功 能 -> Positive(confidence:0.999, ref:Positive) 菜 单 等 各 方 面 的 设 计 比 较 人 性 化
#  手 写 识 别 率 -> Positive(confidence:0.998, ref:Positive) 高
#  备 忘 录 功 能 -> Positive(confidence:0.999, ref:Positive) 还 不 错
#  音 色 -> Positive(confidence:0.998, ref:Positive) 还 算 不 错
#  正 面 设 计 图 案 -> Negative(confidence:0.996, ref:Negative) 不 是 很 协 调
#  体 积 -> Negative(confidence:0.993, ref:Negative) 有 点 大 重
#  按 键 -> Negative(confidence:0.994, ref:Negative) 有 些 硬
#  但 上 市 的 价 格 -> Negative(confidence:0.99, ref:Negative) 却 高 高 在 上
#  秉 承 了 时 尚 高 贵 的 外 形 设 计 -> Positive(confidence:0.993, ref:Positive)
#  简 单 明 了 的 设 计 风 格 -> Positive(confidence:0.999, ref:Positive) 一 直 是 诺 基 亚 直 板 机 的 主 流
#  尺 寸 -> Positive(confidence:0.939, ref:Positive) 还 是 比 较 娇 小 玲 珑
#  方 便 于 携 带 的 同 时 还 带 来 良 好 的 手 感 -> Positive(confidence:0.999, ref:Positive)
#  屏 幕 细 腻 程 度 -> Negative(confidence:0.986, ref:Positive) 不 是 一 般 的 机 型 可 以 比 拟 的
#  的 铃 声 表 现 -> Positive(confidence:0.999, ref:Positive) 也 相 当 不 错
#  穿 透 力 -> Positive(confidence:0.999, ref:Positive) 和 音 量 都 令 人 满 意
#  效 果 -> Positive(confidence:0.998, ref:Positive) 令 人 满 意
#  成 像 效 果 方 面 -> Positive(confidence:0.999, ref:Positive) 表 现 相 当 不 错
#  此 功 能 -> Negative(confidence:0.654, ref:Negative) 形 同 虚 设
#  的 拍 摄 的 功 能 -> Positive(confidence:0.999, ref:Positive) 比 起 有 了 长 足 的 进 步
#  机 身 -> Positive(confidence:0.998, ref:Positive) 小 巧 精 致
#  按 键 设 计 -> Positive(confidence:0.998, ref:Positive) 非 常 经 典
#  整 体 感 -> Positive(confidence:0.998, ref:Positive) 很 强
#  触 感 -> Positive(confidence:0.998, ref:Positive) 很 好
#  弧 线 圆 滑 外 型 -> Positive(confidence:0.998, ref:Positive) 简 约 又 不 失 张 扬
#  还 有 就 是 摄 象 头 的 位 置 -> Negative(confidence:0.997, ref:Negative) 不 太 合 理
#  直 板 -> Positive(confidence:0.999, ref:Positive) 的 简 单 易 用 和 扭 腰 个 性 展 示 的 完 美
#  转 轴 部 分 的 设 计 -> Positive(confidence:0.999, ref:Positive) 也 非 常 考 究
#  各 部 分 设 计 -> Positive(confidence:0.998, ref:Positive) 合 理
#  结 构 -> Positive(confidence:0.998, ref:Positive) 紧 凑 严 密
#  达 到 了 外 型 设 计 -> Positive(confidence:0.999, ref:Positive) 和 功 能 的 完 美 结 合
#  但 外 放 效 果 声 音 -> Positive(confidence:0.998, ref:Positive) 洪 亮
#  耳 机 效 果 -> Positive(confidence:0.998, ref:Positive) 更 是 不 错
#  摄 象 -> Positive(confidence:0.998, ref:Positive) 还 算 可 以
#  按 键 -> Negative(confidence:0.994, ref:Negative) 和 部 件 缝 隙 偏 大
#  做 工 -> Positive(confidence:0.995, ref:Positive) 考 究
#  以 及 简 洁 明 快 的 按 键 设 计 -> Positive(confidence:0.999, ref:Positive)
#  屏 幕 -> Positive(confidence:0.998, ref:Positive) 靓 丽
# 高 分 辨 率 -> 0.999(confidence:Positive) -> 0.999(confidence:Positive) 决 定 了 其 拥 有 比 以 往 采 用 分 辨 率 -> 0.999(confidence:Positive) -> 0.999(confidence:Positive) 的 娱 乐 机 型 更 精 细 逼 真 的 画 面 效 果
#  加 上 内 置 华 丽 的 菜 单 -> Positive(confidence:0.999, ref:Positive) 及 风 格 主 题
#  音 色 -> Positive(confidence:0.998, ref:Positive) 出 众
#  打 造 极 强 立 体 声 效 -> Positive(confidence:0.999, ref:Positive) 的 同 时
#  因 为 画 面 -> Positive(confidence:0.998, ref:Positive) 立 体 感 已 十 足
#  原 装 电 池 续 航 能 力 -> Negative(confidence:0.958, ref:Negative) 不 敢 恭 维
#  系 统 扩 展 性 能 -> Negative(confidence:0.995, ref:Negative) 差
#  电 池 待 机 时 间 -> Negative(confidence:0.994, ref:Negative) 不 长
#  通 话 声 音 -> Negative(confidence:0.996, ref:Negative) 不 够 大
#  的 数 据 线 -> Negative(confidence:0.996, ref:Negative) 真 是 太 落 伍 了
#  摄 像 效 果 -> Negative(confidence:0.994, ref:Negative) 只 能 说 一 般
#  整 体 做 工 -> Positive(confidence:0.998, ref:Positive) 颇 为 精 细
#  黑 色 的 外 观 -> Positive(confidence:0.999, ref:Positive) 给 人 大 气 的 感 觉
#  金 色 的 标 记 与 黑 色 的 整 体 搭 配 -> Positive(confidence:0.998, ref:Positive) 非 常 时 尚
#  随 机 赠 送 的 蓝 牙 耳 机 通 话 质 量 -> Positive(confidence:0.999, ref:Positive) 和 收 听 效 果 都 不 错
#  广 播 音 质 -> Positive(confidence:0.998, ref:Positive) 都 特 别 好
#  效 果 -> Positive(confidence:0.998, ref:Positive) 非 常 不 错
#  但 是 这 款 手 机 的 耳 机 输 出 功 率 -> Negative(confidence:0.997, ref:Negative) 比 较 小
#  拍 摄 效 果 -> Positive(confidence:0.998, ref:Positive) 不 错
#  正 面 的 金 色 和 银 色 的 快 捷 操 作 键 做 工 -> Negative(confidence:0.987, ref:Negative) 稍 微 粗 糙 了 些
#  感 觉 按 键 表 面 -> Negative(confidence:0.993, ref:Negative) 并 不 是 很 平
#  外 置 扬 声 器 -> Negative(confidence:0.965, ref:Positive) 差 的 没 话 说 了
#  声 音 -> Negative(confidence:0.987, ref:Negative) 嘈 杂
#  爆 音 -> Negative(confidence:0.992, ref:Negative) 严 重
#  信 号 -> Positive(confidence:0.998, ref:Positive) 不 错
#  而 且 通 话 的 声 音 -> Positive(confidence:0.993, ref:Positive) 很 大
#  屏 幕 -> Positive(confidence:0.998, ref:Positive) 不 赖
#  亮 度 -> Positive(confidence:0.998, ref:Positive) 高
#  色 彩 -> Positive(confidence:0.998, ref:Positive) 也 很 好
#  只 不 过 美 中 不 足 的 就 是 画 面 -> Negative(confidence:0.996, ref:Negative) 有 点 糙
#  录 音 的 效 果 -> Positive(confidence:0.998, ref:Positive) 我 很 满 意
#  只 不 过 就 是 录 音 的 时 间 -> Negative(confidence:0.997, ref:Negative) 有 点 短
#  音 量 -> Positive(confidence:0.998, ref:Positive) 很 大
#  穿 透 力 -> Positive(confidence:0.998, ref:Positive) 也 不 错
#  而 且 和 弦 的 音 色 -> Positive(confidence:0.999, ref:Positive) 清 脆 饱 满
#  键 盘 -> Negative(confidence:0.993, ref:Negative) 太 小
#  电 池 待 机 时 间 -> Negative(confidence:0.994, ref:Negative) 短
#  收 音 机 的 效 果 -> Positive(confidence:0.998, ref:Positive) 不 错
#  杂 音 -> Positive(confidence:0.991, ref:Positive) 很 少
#  音 量 -> Positive(confidence:0.998, ref:Positive) 也 很 大
#  简 约 而 不 失 时 尚 的 外 型 -> Positive(confidence:0.999, ref:Positive) 靓 丽 的 屏 幕 和 舒 适 的 手 感
#  大 屏 幕 -> Positive(confidence:0.998, ref:Positive) 用 起 来 就 是 一 个 字 爽
#  小 还 配 备 了 独 立 的 扬 声 器 -> Positive(confidence:0.998, ref:Positive)
#  通 话 记 录 -> Positive(confidence:0.998, ref:Positive) 更 为 详 细
#  后 盖 -> Negative(confidence:0.989, ref:Negative) 不 严
#  整 机 设 计 线 条 -> Positive(confidence:0.999, ref:Positive) 简 洁 不 失 流 畅
#  手 感 -> Positive(confidence:0.998, ref:Positive) 不 俗
#  且 整 体 外 观 -> Positive(confidence:0.999, ref:Positive) 透 着 一 种 无 与 伦 比 的 尊 贵
#  屏 幕 -> Positive(confidence:0.998, ref:Positive) 超 靓
#  色 彩 显 示 -> Positive(confidence:0.998, ref:Positive) 不 错
#  文 字 -> Positive(confidence:0.998, ref:Positive) 细 腻
#  支 持 的 五 倍 数 码 变 焦 -> Positive(confidence:0.999, ref:Positive) 同 样 实 用
#  支 持 蓝 牙 功 能 -> Positive(confidence:0.999, ref:Positive) 最 为 实 用
#  价 格 -> Positive(confidence:0.998, ref:Positive) 便 宜
#  短 信 输 入 -> Negative(confidence:0.995, ref:Negative) 慢
#  运 行 速 度 -> Negative(confidence:0.995, ref:Negative) 稍 微 慢 于 存 储 在 内 存 中 游 戏 的 速 度
#  手 机 采 用 了 简 约 的 直 板 式 机 身 设 计 -> Positive(confidence:0.998, ref:Positive)
#  并 且 以 其 独 特 的 双 面 式 设 计 -> Positive(confidence:0.998, ref:Positive)
#  加 入 了 更 多 的 时 尚 元 素 金 属 质 感 极 强 的 机 身 -> Positive(confidence:0.999, ref:Positive) 更 加 优 秀 的 显 示 屏 幕
#  部 分 部 件 采 用 了 做 工 -> Positive(confidence:0.999, ref:Positive) 精 良 的 拉 丝 金 属 材 料
#  用 户 在 使 用 时 也 会 感 受 到 机 身 -> Positive(confidence:0.999, ref:Positive) 的 细 腻
#  索 爱 手 机 采 用 了 色 的 彩 色 的 大 显 示 屏 -> Positive(confidence:0.998, ref:Positive)
#  实 际 应 用 的 色 彩 层 次 感 -> Positive(confidence:0.974, ref:Positive) 较 强
#  同 时 颜 色 -> Negative(confidence:0.948, ref:Positive) 过 度 自 然 真 实
#  在 亮 度 -> Positive(confidence:0.999, ref:Positive) 对 比 度 等 方 面 的 指 数 都 很 出 色
#  设 计 -> Positive(confidence:0.998, ref:Positive) 新 颖
#  三 款 游 戏 的 娱 乐 性 -> Positive(confidence:0.999, ref:Positive) 不 错
#  该 款 手 机 电 池 性 能 -> Negative(confidence:0.995, ref:Negative) 一 般
#  待 机 时 间 -> Negative(confidence:0.995, ref:Negative) 稍 短
#  待 机 时 间 -> Negative(confidence:0.993, ref:Negative) 短
#  同 时 三 星 发 信 息 的 速 度 -> Positive(confidence:0.998, ref:Positive) 比 较 诺 基 亚 速 度 快 了 很 多
#  其 实 它 的 外 观 -> Positive(confidence:0.998, ref:Positive) 很 简 约
#  机 身 设 计 -> Positive(confidence:0.998, ref:Positive) 独 特
#  拍 照 操 作 -> Positive(confidence:0.998, ref:Positive) 简 易 实 用
#  合 并 全 景 照 片 各 种 有 趣 的 画 框 较 高 内 存 容 量 -> Positive(confidence:0.982, ref:Positive) 让 不 是 专 业 的 数 码 拍 照 手 机 用 户 使 用 起 来 得 心 应 手
#  图 像 发 送 步 骤 -> Positive(confidence:0.998, ref:Positive) 简 单
#  娱 乐 性 能 -> Positive(confidence:0.998, ref:Positive) 强 大
#  音 质 -> Positive(confidence:0.998, ref:Positive) 也 不 错
#  色 彩 的 光 亮 -> Positive(confidence:0.999, ref:Positive) 柔 和 细 腻 度 都 不 错
#  按 键 -> Positive(confidence:0.979, ref:Positive) 比 较 大
#  兼 容 性 -> Positive(confidence:0.996, ref:Positive) 较 强
#  这 种 功 能 -> Positive(confidence:0.998, ref:Positive) 比 较 新 鲜
#  影 像 质 量 -> Negative(confidence:0.995, ref:Negative) 还 存 在 缺 陷
#  虽 然 在 户 外 环 境 下 色 彩 还 原 -> Positive(confidence:0.998, ref:Positive) 图 像 层 次 感 较 好
#  图 像 细 节 -> Negative(confidence:0.995, ref:Negative) 有 失 真
#  拥 有 良 好 的 手 感 -> Positive(confidence:0.998, ref:Positive)
#  使 机 身 线 条 -> Positive(confidence:0.999, ref:Positive) 非 常 圆 滑
#  的 三 围 尺 寸 以 及 的 适 中 重 量 -> Positive(confidence:0.998, ref:Positive)
#  采 用 了 出 众 的 双 彩 屏 幕 设 计 -> Positive(confidence:0.999, ref:Positive)
#  画 质 -> Positive(confidence:0.999, ref:Positive) 细 腻 并 可 冲 印 成 照 片 而 毫 不 逊 色
#  还 提 供 外 屏 快 速 自 拍 功 能 -> Positive(confidence:0.999, ref:Positive)
#  保 持 了 机 身 整 体 外 观 -> Positive(confidence:0.999, ref:Positive) 浑 然 一 体
#  显 示 效 果 -> Positive(confidence:0.999, ref:Positive) 出 色 了 不 少
#  造 型 -> Positive(confidence:0.983, ref:Positive) 明 显 成 熟
#  中 间 的 缝 隙 -> Negative(confidence:0.995, ref:Negative) 就 太 大 了 点
#  键 盘 设 计 -> Positive(confidence:0.999, ref:Positive) 也 十 分 简 洁 漂 亮
#  做 工 -> Positive(confidence:0.995, ref:Positive) 应 该 不 会 差
#  但 速 度 -> Positive(confidence:0.997, ref:Positive) 绝 对 比 红 外 要 快
#  外 型 -> Positive(confidence:0.998, ref:Positive) 好 看 了
#  但 实 用 性 -> Negative(confidence:0.993, ref:Negative) 下 降 了
#  另 外 拍 摄 模 式 -> Negative(confidence:0.977, ref:Negative) 也 很 少
#  小 的 美 丽 外 形 -> Negative(confidence:0.861, ref:Positive)
#  专 业 音 乐 播 放 -> Positive(confidence:0.998, ref:Positive)
#  以 及 个 性 化 的 主 题 -> Positive(confidence:0.998, ref:Positive)
#  没 有 个 性 化 短 信 提 示 音 -> Negative(confidence:0.996, ref:Negative)
#  缺 少 给 专 用 文 件 夹 与 短 信 加 密 功 能 -> Negative(confidence:0.989, ref:Negative)
#  寸 的 屏 幕 -> Negative(confidence:0.556, ref:Negative) 可 以 说 是 小 最 让 人 遗 憾 的 硬 件 缺 憾 了
#  播 放 的 视 频 格 式 -> Negative(confidence:0.997, ref:Negative) 与 音 乐 格 式 太 少
#  显 示 效 果 -> Positive(confidence:0.999, ref:Positive) 十 分 的 令 人 满 意
#  光 度 -> Positive(confidence:0.997, ref:Positive) 适 中
#  光 线 -> Positive(confidence:0.998, ref:Positive) 柔 和
#  同 时 具 有 丰 富 的 短 信 息 输 入 联 想 功 能 -> Positive(confidence:0.999, ref:Positive)
#  其 可 玩 性 -> Positive(confidence:0.999, ref:Positive) 还 是 比 较 令 人 满 意 的
#  游 戏 音 乐 -> Positive(confidence:0.987, ref:Positive) 轻 快
#  动 作 画 面 -> Positive(confidence:0.975, ref:Positive) 动 感 刺 激
#  铃 声 效 果 -> Positive(confidence:0.999, ref:Positive) 悠 扬 动 听 悦 耳 清 脆
#  而 且 功 能 按 键 -> Negative(confidence:0.995, ref:Negative) 排 列 的 过 于 拥 挤
#  屏 幕 的 显 示 面 积 -> Negative(confidence:0.993, ref:Negative) 不 是 很 大
#  而 且 这 款 摩 托 罗 拉 手 机 的 内 部 屏 幕 显 示 效 果 -> Negative(confidence:0.995, ref:Negative) 也 不 是 十 分 的 令 人 满 意
#  声 音 录 制 -> Positive(confidence:0.999, ref:Positive) 实 在 是 一 个 极 为 实 用 的 功 能
#  反 映 速 度 -> Negative(confidence:0.995, ref:Negative) 超 慢
#  做 工 -> Negative(confidence:0.992, ref:Negative) 不 如 其 他 国 际 品 牌 精 致
#  并 且 屏 幕 与 方 向 键 之 间 的 空 隙 -> Negative(confidence:0.996, ref:Negative) 太 大
#  传 输 方 式 -> Negative(confidence:0.993, ref:Negative) 欠 缺
#  况 且 机 子 本 身 内 置 图 片 铃 声 -> Negative(confidence:0.995, ref:Negative) 又 极 其 单 调
#  外 观 -> Positive(confidence:0.998, ref:Positive) 炫 酷
#  三 菱 拥 有 炫 酷 的 外 形 -> Positive(confidence:0.998, ref:Positive)
#  内 置 天 线 的 设 计 使 得 外 观 -> Positive(confidence:0.999, ref:Positive) 更 显 清 新 简 洁
#  三 菱 专 利 的 整 体 镜 面 外 屏 -> Positive(confidence:0.996, ref:Positive) 流 露 出 的 时 尚 感 觉 让 人 一 见 倾 心
#  音 效 -> Positive(confidence:0.998, ref:Positive) 出 色
#  铃 声 的 音 量 -> Positive(confidence:0.999, ref:Positive) 得 益 于 良 好 的 独 立 扬 声 器 设 计 而 大 大 增 强
#  铃 声 音 效 -> Positive(confidence:0.998, ref:Positive) 悠 扬 洪 亮
#  即 使 冲 印 成 寸 照 片 也 是 效 果 -> Positive(confidence:0.999, ref:Positive) 出 众
#  三 菱 还 具 有 一 个 很 有 创 意 的 功 能 [UNK] [UNK] 内 置 了 精 美 的 像 框 -> Positive(confidence:0.999, ref:Positive)
#  拍 摄 功 能 -> Positive(confidence:0.999, ref:Positive) 的 强 大 使 足 以 媲 美 一 台 高 端 数 码 相 机
#  功 能 -> Positive(confidence:0.998, ref:Positive) 强 大
#  待 机 -> Positive(confidence:0.998, ref:Positive) 强 悍
#  这 也 从 另 一 个 侧 面 体 现 出 电 源 管 理 系 统 -> Positive(confidence:0.999, ref:Positive) 的 出 色
#  铃 声 音 量 -> Negative(confidence:0.995, ref:Negative) 不 够 大
#  屏 幕 -> Positive(confidence:0.998, ref:Positive) 艳 丽 且 细 腻
#  万 像 素 摄 像 头 功 能 -> Positive(confidence:0.999, ref:Positive) 还 可 以
#  效 果 -> Negative(confidence:0.993, ref:Negative) 一 般
#  但 是 我 觉 得 手 机 能 拍 出 这 种 效 果 -> Positive(confidence:0.997, ref:Positive) 我 挺 满 意
#  夜 晚 拍 摄 效 果 -> Negative(confidence:0.993, ref:Negative) 不 怎 么 好
#  本 机 内 存 -> Positive(confidence:0.997, ref:Positive) 比 较 大
#  传 输 速 度 -> Positive(confidence:0.998, ref:Positive) 还 可 以
#  使 用 -> Positive(confidence:0.998, ref:Positive) 非 常 人 性 化
#  快 捷 键 设 计 -> Positive(confidence:0.999, ref:Positive) 的 很 方 便
#  磨 沙 的 外 壳 不 易 留 下 指 纹 -> Positive(confidence:0.989, ref:Positive)
#  日 历 日 程 表 功 能 -> Positive(confidence:0.999, ref:Positive) 不 错
#  比 红 外 方 便 且 速 度 -> Positive(confidence:0.998, ref:Positive) 快
#  网 上 有 不 少 朋 友 反 映 滑 盖 -> Negative(confidence:0.992, ref:Negative) 容 易 松 动
#  三 星 的 手 机 编 辑 软 件 传 输 速 度 -> Negative(confidence:0.997, ref:Negative) 太 慢
#  现 在 市 面 上 的 配 件 -> Negative(confidence:0.985, ref:Negative) 很 少
#  通 话 音 质 -> Positive(confidence:0.998, ref:Positive) 较 好
#  音 量 -> Positive(confidence:0.998, ref:Positive) 大
#  来 电 铃 声 音 量 -> Positive(confidence:0.999, ref:Positive) 也 够 大
#  手 写 识 别 灵 敏 度 -> Positive(confidence:0.998, ref:Positive) 高
#  录 音 灵 敏 度 -> Positive(confidence:0.998, ref:Positive) 高
#  音 质 -> Positive(confidence:0.998, ref:Positive) 清 晰
#  拍 的 照 片 -> Positive(confidence:0.998, ref:Positive) 很 不 错
#  设 计 -> Positive(confidence:0.998, ref:Positive) 细 节 人 性 化
#  备 忘 录 功 能 -> Positive(confidence:0.998, ref:Positive) 强 大
#  其 音 乐 播 放 能 力 -> Positive(confidence:0.996, ref:Positive) 自 是 不 容 忽 视 的
#  整 体 的 表 现 -> Negative(confidence:0.984, ref:Negative) 并 不 是 非 常 出 色
#  整 体 的 层 次 感 -> Positive(confidence:0.998, ref:Positive) 非 常 强
#  还 是 显 示 效 果 -> Positive(confidence:0.999, ref:Positive) 上 都 有 不 小 的 提 高
#  而 且 色 彩 -> Positive(confidence:0.999, ref:Positive) 也 要 比 更 加 艳 丽
#  还 好 的 成 像 效 果 -> Positive(confidence:0.995, ref:Positive) 比 较 清 晰
#  在 加 上 几 乎 为 的 快 门 时 滞 和 超 高 的 快 门 速 度 -> Positive(confidence:0.999, ref:Positive)
#  在 强 光 下 拍 摄 出 的 图 片 -> Negative(confidence:0.996, ref:Negative) 有 点 偏 色
#  长 度 -> Negative(confidence:0.987, ref:Positive) 和 厚 度 均 比 要 小 点
#  而 且 整 体 的 造 型 -> Positive(confidence:0.999, ref:Positive) 更 为 圆 滑
#  机 身 各 处 的 接 合 缝 -> Positive(confidence:0.999, ref:Positive) 均 匀 一 致
#  不 过 稍 感 遗 憾 的 是 各 按 键 之 间 的 缝 隙 -> Negative(confidence:0.996, ref:Negative) 有 些 大
#  的 按 键 -> Positive(confidence:0.992, ref:Positive) 比 较 柔 软
#  整 机 做 工 -> Positive(confidence:0.998, ref:Positive) 不 错
#  外 形 设 计 -> Positive(confidence:0.998, ref:Positive) 很 朴 实
#  左 侧 上 部 设 计 -> Positive(confidence:0.998, ref:Positive) 很 是 特 别
#  音 量 -> Positive(confidence:0.999, ref:Positive) 和 穿 透 力 都 非 常 不 错
#  各 频 段 的 音 色 -> Positive(confidence:0.999, ref:Positive) 表 现 也 十 分 出 色
#  音 域 -> Positive(confidence:0.998, ref:Positive) 宽 广 自 然
#  铃 声 的 效 果 -> Positive(confidence:0.999, ref:Positive) 令 人 感 到 满 意
#  耳 机 的 音 乐 效 果 -> Positive(confidence:0.999, ref:Positive) 表 现 也 很 不 错
#  它 的 屏 幕 显 示 -> Positive(confidence:0.999, ref:Positive) 也 是 极 其 清 晰 美 观
#  字 体 -> Positive(confidence:0.998, ref:Positive) 清 楚
#  按 键 -> Positive(confidence:0.998, ref:Positive) 也 是 很 舒 适
#  它 标 配 的 锂 离 子 电 池 -> Positive(confidence:0.999, ref:Positive) 很 好 用
#  续 航 能 力 -> Positive(confidence:0.998, ref:Positive) 的 表 现 相 当 令 人 满 意
#  它 还 具 备 了 强 大 的 上 网 功 能 -> Positive(confidence:0.999, ref:Positive)
#  的 屏 幕 分 辨 率 -> Negative(confidence:0.996, ref:Negative) 不 够 精 细
#  它 的 机 身 -> Negative(confidence:0.982, ref:Negative) 略 长
#  娱 乐 功 能 -> Negative(confidence:0.995, ref:Negative) 不 强 大
#  它 的 听 筒 设 计 -> Negative(confidence:0.971, ref:Negative) 较 小
#  声 音 -> Negative(confidence:0.992, ref:Negative) 不 是 很 响 亮
#  屏 幕 -> Negative(confidence:0.996, ref:Negative) 和 弦 摄 像 头 较 差
#  质 量 -> Positive(confidence:0.998, ref:Positive) 好
#  运 算 -> Positive(confidence:0.998, ref:Positive) 快
#  声 音 -> Positive(confidence:0.998, ref:Positive) 清 楚 而 且 大
#  声 音 -> Negative(confidence:0.982, ref:Negative) 小 有 回 音
#  屏 幕 -> Positive(confidence:0.998, ref:Positive) 好
#  和 弦 -> Positive(confidence:0.998, ref:Positive) 清 脆
#  铃 声 屏 幕 -> Positive(confidence:0.998, ref:Positive) 俱 佳
#  可 惜 性 价 比 -> Negative(confidence:0.993, ref:Negative) 差
#  听 筒 声 音 -> Negative(confidence:0.994, ref:Negative) 普 遍 小 了 点 中 国 人 多
#  性 价 比 -> Positive(confidence:0.999, ref:Positive) 在 所 有 洋 品 牌 中 来 说 是 最 好 的
#  外 型 -> Positive(confidence:0.997, ref:Positive) 时 尚
#  待 机 时 间 -> Positive(confidence:0.998, ref:Positive) 够 长
#  缺 点 是 做 工 -> Negative(confidence:0.994, ref:Negative) 差 了 点
#  听 筒 声 音 -> Positive(confidence:0.998, ref:Positive) 好
#  优 美 流 畅 的 线 条 设 计 -> Positive(confidence:0.999, ref:Positive)
#  圆 润 光 滑 的 边 角 工 艺 -> Positive(confidence:0.999, ref:Positive)
#  屏 幕 色 彩 层 次 感 -> Positive(confidence:0.977, ref:Positive) 较 强
#  同 时 颜 色 -> Negative(confidence:0.948, ref:Positive) 过 度 自 然 真 实
#  在 亮 度 -> Positive(confidence:0.999, ref:Positive) 对 比 度 等 方 面 的 指 数 都 很 出 色
#  设 计 -> Positive(confidence:0.998, ref:Positive) 新 颖
#  独 特 的 曲 线 型 设 计 -> Positive(confidence:0.998, ref:Positive)
#  同 时 具 有 丰 富 的 短 信 息 联 想 功 能 -> Positive(confidence:0.999, ref:Positive)
#  三 款 游 戏 的 可 玩 性 -> Positive(confidence:0.998, ref:Positive) 较 高
#  短 信 功 能 -> Positive(confidence:0.998, ref:Positive) 方 便
#  输 入 法 -> Positive(confidence:0.998, ref:Positive) 好 用
#  短 信 功 能 -> Positive(confidence:0.999, ref:Positive) 非 常 实 用
#  时 钟 功 能 -> Positive(confidence:0.998, ref:Positive) 很 好 用
#  但 拍 摄 效 果 -> Positive(confidence:0.998, ref:Positive) 清 晰
#  外 屏 色 彩 虹 来 电 显 示 灯 -> Positive(confidence:0.999, ref:Positive) 非 常 漂 亮
#  显 示 图 片 -> Positive(confidence:0.998, ref:Positive) 清 晰
#  色 彩 -> Positive(confidence:0.998, ref:Positive) 饱 满
#  和 弦 铃 声 -> Positive(confidence:0.999, ref:Positive) 的 表 现 浑 厚 有 力
#  穿 透 力 -> Positive(confidence:0.998, ref:Positive) 好
#  清 晰 的 通 话 音 质 -> Positive(confidence:0.998, ref:Positive)
#  响 亮 的 免 提 通 话 -> Positive(confidence:0.998, ref:Positive)
#  商 务 功 能 -> Positive(confidence:0.998, ref:Positive) 一 应 俱 全
#  而 且 还 具 备 蓝 牙 -> Positive(confidence:0.999, ref:Positive) 红 外 传 输 等 先 进 功 能
#  的 体 积 -> Positive(confidence:0.997, ref:Positive) 和 机 身 重 量 算 是 小 巧 类 了
#  按 键 -> Positive(confidence:0.998, ref:Positive) 宽 大
#  手 感 -> Positive(confidence:0.998, ref:Positive) 很 好
#  整 机 做 工 -> Positive(confidence:0.998, ref:Positive) 优 秀
#  那 的 短 信 功 能 -> Positive(confidence:0.999, ref:Positive) 就 更 加 人 性 化 了
#  如 果 上 市 价 格 -> Negative(confidence:0.973, ref:Negative) 便 宜 一 点
#  电 话 本 -> Negative(confidence:0.995, ref:Negative) 不 好 用
#  待 机 时 间 -> Negative(confidence:0.759, ref:Negative) 实 在 是 不 敢 恭 维
#  屏 幕 的 分 辨 率 -> Negative(confidence:0.995, ref:Negative) 很 低
#  有 铃 声 -> Negative(confidence:0.994, ref:Negative) 太 小 的 问 题
#  电 话 本 -> Negative(confidence:0.995, ref:Negative) 不 好 用
#  烦 人 的 短 信 住 逐 行 阅 读 方 式 -> Negative(confidence:0.671, ref:Negative) 菜 单
#  待 机 时 间 -> Negative(confidence:0.759, ref:Negative) 实 在 是 不 敢 恭 维
#  屏 幕 的 分 辨 率 -> Negative(confidence:0.995, ref:Negative) 很 低
#  有 铃 声 -> Negative(confidence:0.994, ref:Negative) 太 小 的 问 题
#  耳 机 质 量 -> Negative(confidence:0.993, ref:Negative) 不 好
#  但 价 格 -> Negative(confidence:0.994, ref:Negative) 偏 高 一 直 没 能 买
#  喜 欢 上 的 原 因 当 然 是 她 唯 美 的 外 表 -> Positive(confidence:0.999, ref:Positive) 和 恰 到 好 处 的 颜 色 搭 配
#  机 身 外 形 设 计 -> Positive(confidence:0.999, ref:Positive) 时 尚 前 卫 有 个 性
#  她 迷 幻 的 色 彩 -> Positive(confidence:0.996, ref:Positive) 打 动 了 无 数 人 的 心
#  功 能 -> Positive(confidence:0.998, ref:Positive) 自 然 比 一 般 相 机 要 多 许 多
#  开 机 处 设 计 -> Negative(confidence:0.996, ref:Negative) 真 的 很 失 败
#  所 以 在 好 看 的 亮 度 外 表 -> Positive(confidence:0.999, ref:Positive) 下
#  所 以 感 觉 按 键 -> Negative(confidence:0.996, ref:Negative) 排 列 得 太 过 密 集 了
#  第 一 次 用 它 的 键 盘 -> Negative(confidence:0.991, ref:Negative) 时 竟 然 觉 得 太 生 硬 了
#  导 航 键 的 面 积 -> Negative(confidence:0.993, ref:Negative) 设 计 的 也 很 小
#  闹 钟 功 能 -> Negative(confidence:0.996, ref:Negative) 设 计 不 具 备 人 性 化
#  目 前 市 场 价 格 -> Negative(confidence:0.992, ref:Negative) 还 是 比 较 高
#  来 点 闪 -> Positive(confidence:0.997, ref:Positive) 很 有 创 意
#  动 画 屏 保 -> Positive(confidence:0.998, ref:Positive) 还 可 以
#  发 短 信 同 时 可 以 加 上 本 机 附 带 的 图 标 动 画 -> Positive(confidence:0.998, ref:Positive) 和 铃 声 也 是 好 有 创 意 的
#  铃 声 -> Positive(confidence:0.998, ref:Positive) 很 细 腻
#  独 特 的 外 观 设 计 -> Positive(confidence:0.997, ref:Positive) 也 是 小 的 亮 点 之 处
#  夜 光 外 壳 -> Positive(confidence:0.993, ref:Positive) 也 是 小 的 优 点 之 一
#  速 度 -> Negative(confidence:0.969, ref:Negative) 及 慢
#  声 音 -> Negative(confidence:0.994, ref:Negative) 太 小
#  屏 幕 -> Positive(confidence:0.998, ref:Negative) 有 亮 点
#  听 筒 声 音 -> Negative(confidence:0.995, ref:Negative) 太 小
#  短 信 编 辑 时 的 按 键 -> Negative(confidence:0.997, ref:Negative) 真 的 不 好 使
#  信 号 -> Negative(confidence:0.993, ref:Negative) 不 怎 么 好
#  空 间 -> Negative(confidence:0.994, ref:Negative) 太 小
#  短 信 储 存 空 间 -> Negative(confidence:0.996, ref:Negative) 太 小
#  而 且 耳 机 -> Negative(confidence:0.989, ref:Negative) 太 硬
#  手 机 设 置 参 数 -> Negative(confidence:0.92, ref:Negative) 真 的 好 麻 烦
#  外 观 -> Negative(confidence:0.99, ref:Negative) 真 不 是 怎 么 很 好 看
#  都 说 飞 离 谱 的 手 机 的 电 池 -> Positive(confidence:0.999, ref:Negative) 很 耐 用
#  游 戏 方 面 -> Negative(confidence:0.994, ref:Negative) 太 烂
#  电 话 簿 查 询 -> Negative(confidence:0.995, ref:Negative) 起 来 太 麻 烦 了
#  整 机 线 条 -> Positive(confidence:0.998, ref:Positive) 流 畅
#  边 角 -> Negative(confidence:0.592, ref:Positive) 过 度 均 匀 而 且 圆 润
#  颜 色 搭 配 -> Positive(confidence:0.997, ref:Positive) 协 调
#  屏 幕 的 色 彩 表 现 力 -> Positive(confidence:0.999, ref:Positive) 色 彩 的 层 次 感 很 出 色
#  且 屏 幕 色 彩 的 过 度 -> Positive(confidence:0.999, ref:Positive) 还 原 度 以 及 屏 幕 的 亮 度 饱 和 度 也 都 是 非 常 的 出 色
#  操 作 方 法 -> Positive(confidence:0.998, ref:Positive) 简 单 便 捷
#  这 项 功 能 -> Positive(confidence:0.999, ref:Positive) 还 是 十 分 的 实 用 的
#  这 样 丰 富 的 电 话 簿 查 找 功 能 -> Positive(confidence:0.999, ref:Positive)
#  配 合 这 款 手 机 丰 富 的 短 信 息 输 入 联 想 功 能 -> Positive(confidence:0.999, ref:Positive)
#  铃 声 效 果 -> Positive(confidence:0.998, ref:Positive) 清 脆 动 听
#  游 戏 数 量 -> Negative(confidence:0.996, ref:Negative) 略 显 不 足
#  做 工 -> Positive(confidence:0.998, ref:Positive) 较 好
#  手 感 -> Positive(confidence:0.998, ref:Positive) 不 错
#  俱 备 较 高 的 万 像 素 摄 像 头 -> Positive(confidence:0.999, ref:Positive)
#  画 面 清 晰 度 -> Positive(confidence:0.999, ref:Positive) 比 较 细 腻
#  播 放 有 声 动 画 -> Positive(confidence:0.999, ref:Positive) 也 比 较 顺 畅
#  主 流 时 尚 的 蓝 牙 -> Positive(confidence:0.998, ref:Positive)
#  让 拥 有 更 加 广 泛 的 软 件 扩 展 -> Positive(confidence:0.999, ref:Positive)
#  边 角 按 键 -> Negative(confidence:0.995, ref:Negative) 显 小
#  扬 声 器 -> Negative(confidence:0.989, ref:Negative) 有 暇 疵
#  音 乐 效 果 -> Negative(confidence:0.996, ref:Negative) 有 失 真 现 象
#  锂 电 池 兼 容 性 -> Negative(confidence:0.996, ref:Negative) 不 够 强
#  效 果 -> Positive(confidence:0.998, ref:Positive) 不 错
#  使 用 -> Negative(confidence:0.99, ref:Negative) 不 方 便
#  整 部 机 上 按 键 -> Positive(confidence:0.998, ref:Positive) 排 列 整 齐
#  里 面 我 个 人 觉 得 比 较 实 用 的 功 能 是 相 框 -> Positive(confidence:0.998, ref:Positive) 和 快 捷 键 功 能
#  个 人 觉 得 收 音 功 能 -> Positive(confidence:0.998, ref:Positive) 是 最 实 用 的
#  但 我 觉 得 实 用 性 -> Negative(confidence:0.995, ref:Negative) 一 般
#  待 机 时 间 -> Negative(confidence:0.993, ref:Negative) 短
#  另 一 个 就 是 其 自 带 内 存 -> Negative(confidence:0.996, ref:Negative) 太 小 了
#  位 于 屏 幕 下 方 的 上 网 键 -> Negative(confidence:0.994, ref:Negative) 很 碍 手
#  硕 大 的 屏 幕 -> Positive(confidence:0.998, ref:Positive)
#  突 出 的 键 盘 -> Positive(confidence:0.99, ref:Positive)
#  夸 张 的 自 拍 镜 -> Negative(confidence:0.985, ref:Positive)
#  屏 幕 -> Positive(confidence:0.998, ref:Positive) 出 色
#  色 彩 -> Positive(confidence:0.998, ref:Positive) 鲜 艳
#  显 示 效 果 -> Positive(confidence:0.998, ref:Positive) 出 众
#  操 作 -> Positive(confidence:0.998, ref:Positive) 起 来 更 方 便
#  音 响 -> Positive(confidence:0.998, ref:Positive) 十 足
# 和 弦 铃 声 -> 0.999(confidence:Positive) -> 0.999(confidence:Positive) 且 铃 声 -> 0.999(confidence:Positive) -> 0.999(confidence:Positive) 雄 厚 有 力
#  对 音 色 的 还 原 能 力 -> Positive(confidence:0.998, ref:Positive) 较 好
#  扩 展 性 -> Positive(confidence:0.998, ref:Positive) 强
#  较 高 的 性 价 比 -> Positive(confidence:0.998, ref:Positive) 我 们 也 不 能 忽 视
#  屏 幕 分 辨 率 -> Negative(confidence:0.995, ref:Negative) 低
#  因 此 使 得 屏 幕 画 面 -> Negative(confidence:0.996, ref:Negative) 不 够 精 细
#  整 机 做 工 -> Negative(confidence:0.996, ref:Negative) 不 够 精 细
#  部 分 机 子 的 外 壳 之 间 的 连 接 处 缝 隙 -> Negative(confidence:0.997, ref:Negative) 过 大
# 具 体 表 现 在 接 电 话 一 方 听 到 说 话 方 周 围 噪 音 -> 0.997(confidence:Negative) -> 0.997(confidence:Negative) 过 大 且 噪 音 -> 0.997(confidence:Negative) -> 0.997(confidence:Negative) 和 通 话 声 音 在 一 个 层 面 上
#  画 面 色 彩 -> Positive(confidence:0.998, ref:Positive) 细 腻
#  短 信 息 -> Positive(confidence:0.999, ref:Positive) 和 彩 信 功 能 都 非 常 实 用
#  操 作 -> Positive(confidence:0.998, ref:Positive) 十 分 简 单
#  用 的 系 统 -> Positive(confidence:0.999, ref:Positive) 还 是 很 稳 定 的
#  不 过 软 件 兼 容 性 -> Negative(confidence:0.996, ref:Negative) 不 好
#  内 存 -> Negative(confidence:0.994, ref:Negative) 实 在 小
#  但 听 起 来 效 果 -> Negative(confidence:0.996, ref:Negative) 还 不 是 那 么 理 想
#  噪 点 -> Negative(confidence:0.988, ref:Negative) 多
#  再 就 是 拍 摄 存 储 间 隔 时 间 -> Negative(confidence:0.996, ref:Negative) 太 长
#  外 观 设 计 -> Positive(confidence:0.998, ref:Positive) 的 不 错
#  手 感 -> Positive(confidence:0.999, ref:Positive) 和 屏 幕 效 果 也 还 可 以
#  手 感 -> Positive(confidence:0.998, ref:Positive) 不 错
#  就 是 屏 幕 -> Negative(confidence:0.996, ref:Negative) 感 觉 有 点 暗
#  摄 像 头 照 出 来 的 像 片 效 果 -> Positive(confidence:0.999, ref:Positive) 也 还 可 以
#  通 话 键 和 关 机 键 的 设 计 -> Positive(confidence:0.999, ref:Positive) 新 颖
#  的 按 键 设 计 -> Positive(confidence:0.999, ref:Positive) 人 性 化 非 常 好
#  就 是 按 键 按 下 去 手 感 -> Negative(confidence:0.996, ref:Negative) 不 好
#  设 计 -> Positive(confidence:0.998, ref:Positive) 不 错
#  功 能 -> Positive(confidence:0.998, ref:Positive) 实 用
#  操 作 功 能 -> Positive(confidence:0.998, ref:Positive) 简 单
#  另 外 就 是 内 存 -> Negative(confidence:0.996, ref:Negative) 小 了 点 儿
#  尺 寸 -> Positive(confidence:0.998, ref:Positive) 非 常 合 适
#  滑 盖 -> Positive(confidence:0.998, ref:Positive) 也 很 灵 巧
#  寸 的 显 示 屏 幕 -> Positive(confidence:0.999, ref:Positive) 给 人 感 觉 相 当 的 大 气
#  后 盖 -> Positive(confidence:0.998, ref:Positive) 结 合 也 很 紧 密
#  这 款 机 子 从 外 观 上 讲 充 分 显 示 出 了 优 秀 精 致 的 做 工 -> Positive(confidence:0.999, ref:Positive)
#  此 机 操 作 -> Positive(confidence:0.998, ref:Positive) 很 轻 松
#  快 捷 键 -> Positive(confidence:0.998, ref:Positive) 的 搭 配 也 合 理
#  音 质 方 面 -> Negative(confidence:0.995, ref:Negative) 是 差 了 点
#  象 素 的 摄 象 头 -> Positive(confidence:0.999, ref:Positive) 更 是 一 个 非 常 理 想 的 配 置
#  屏 幕 分 辨 -> Positive(confidence:0.997, ref:Positive) 上 略 胜 一 筹
#  的 铃 声 -> Positive(confidence:0.974, ref:Positive) 个 人 觉 得 还 是 相 当 大 了
#  听 筒 声 音 -> Positive(confidence:0.993, ref:Positive) 也 比 较 大
#  电 话 薄 的 功 能 -> Negative(confidence:0.995, ref:Negative) 就 显 得 很 不 科 学 了
#  此 机 最 大 的 问 题 便 是 触 摸 键 -> Negative(confidence:0.981, ref:Negative) 太 灵 敏 了
#  拍 照 效 果 -> Positive(confidence:0.998, ref:Positive) 不 错
#  外 观 -> Positive(confidence:0.998, ref:Positive) 吸 引 人
#  同 步 效 果 -> Positive(confidence:0.998, ref:Positive) 相 当 不 错
#  立 体 声 耳 机 音 质 -> Positive(confidence:0.999, ref:Positive) 非 常 好
#  也 是 一 个 品 质 -> Positive(confidence:0.999, ref:Positive) 不 错 的
#  开 机 读 卡 速 度 -> Negative(confidence:0.995, ref:Negative) 比 较 慢
#  性 价 比 -> Positive(confidence:0.998, ref:Positive) 高
#  软 件 -> Positive(confidence:0.998, ref:Positive) 使 用 还 可 以
#  要 说 的 是 转 接 线 质 量 -> Negative(confidence:0.996, ref:Negative) 不 好
# 随 机 配 的 播 放 器 -> 0.999(confidence:Positive) -> 0.999(confidence:Positive) 感 觉 比 里 的 播 放 器 -> 0.999(confidence:Positive) -> 0.999(confidence:Positive) 好 一 些
#  感 觉 音 乐 目 录 -> Negative(confidence:0.996, ref:Negative) 有 点 乱
#  手 感 -> Positive(confidence:0.998, ref:Positive) 细 腻
#  做 工 -> Positive(confidence:0.998, ref:Positive) 出 色
#  按 键 手 感 -> Positive(confidence:0.998, ref:Positive) 很 好
#  传 承 了 三 星 经 典 滑 盖 设 计 -> Positive(confidence:0.999, ref:Positive)
#  她 万 色 的 高 清 晰 的 液 晶 屏 -> Positive(confidence:0.999, ref:Positive)
#  还 是 从 色 彩 -> Positive(confidence:0.998, ref:Positive) 上 都 让 人 怦 然 心 动
#  声 音 -> Positive(confidence:0.998, ref:Positive) 优 美 动 听
#  同 时 具 有 强 大 的 多 媒 体 功 能 -> Positive(confidence:0.999, ref:Positive)
#  电 话 本 更 是 具 有 条 的 大 容 量 存 储 -> Positive(confidence:0.999, ref:Positive)
#  但 实 际 使 用 中 按 键 -> Negative(confidence:0.996, ref:Negative) 偏 小
#  操 纵 -> Negative(confidence:0.99, ref:Negative) 不 方 便
#  整 机 -> Negative(confidence:0.993, ref:Negative) 也 偏 小 一 点
#  声 场 -> Negative(confidence:0.994, ref:Negative) 还 是 有 些 局 促
#  空 间 感 -> Negative(confidence:0.994, ref:Negative) 不 强
#  样 子 -> Positive(confidence:0.997, ref:Positive) 讨 人 喜 欢
#  也 就 是 说 红 外 线 的 操 作 -> Positive(confidence:0.999, ref:Positive) 简 单 易 用
#  来 电 防 火 墙 功 能 -> Positive(confidence:0.998, ref:Positive) 挺 强
#  待 机 时 间 -> Negative(confidence:0.993, ref:Negative) 短
#  铃 声 -> Negative(confidence:0.993, ref:Negative) 不 够 大
#  简 洁 的 流 线 型 设 计 -> Positive(confidence:0.999, ref:Positive) 银 翼 合 金 外 壳 质 感 配 以 可 度 旋 转 的 折 叠 式 前 盖
#  做 工 -> Positive(confidence:0.996, ref:Positive) 精 细
#  选 用 了 极 具 魅 力 的 蓝 色 键 盘 背 光 灯 -> Positive(confidence:0.998, ref:Positive)
#  光 线 强 度 -> Positive(confidence:0.988, ref:Positive) 也 较 大
#  这 款 手 机 的 转 轴 的 紧 密 性 -> Positive(confidence:0.999, ref:Positive) 表 现 出 色
#  整 体 的 连 贯 性 能 -> Positive(confidence:0.999, ref:Positive) 表 现 出 色
#  具 有 丰 富 的 中 文 输 入 联 想 功 能 -> Positive(confidence:0.999, ref:Positive)
#  这 样 的 配 置 使 得 在 铃 声 的 表 现 力 方 面 -> Positive(confidence:0.999, ref:Positive) 还 是 比 较 的 丰 富 多 彩 的
#  铃 声 -> Positive(confidence:0.998, ref:Positive) 响 亮 清 澈 的
#  音 色 -> Positive(confidence:0.998, ref:Positive) 纯 正 而 丰 富
#  手 机 预 置 的 游 戏 数 量 -> Negative(confidence:0.996, ref:Positive) 和 质 量 都 显 得 比 较 一 般
#  整 体 的 游 戏 娱 乐 性 -> Negative(confidence:0.994, ref:Positive) 并 不 是 很 强
#  游 戏 的 连 贯 性 -> Negative(confidence:0.996, ref:Negative) 也 表 现 一 般
#  整 体 的 操 控 性 能 -> Negative(confidence:0.996, ref:Negative) 表 现 平 平
#  的 价 位 -> Positive(confidence:0.996, ref:Positive) 是 比 较 合 理 的
#  而 且 音 质 -> Positive(confidence:0.998, ref:Positive) 也 是 可 以 的
#  来 电 铃 声 -> Positive(confidence:0.998, ref:Positive) 超 大
#  其 次 手 机 的 手 感 -> Positive(confidence:0.998, ref:Positive) 和 质 量 让 人 放 心
#  手 机 -> Negative(confidence:0.927, ref:Positive) 不 算 大
#  华 盖 -> Positive(confidence:0.999, ref:Positive) 也 很 设 计 的 也 很 好
#  功 能 -> Positive(confidence:0.998, ref:Positive) 很 强 大
#  容 量 -> Positive(confidence:0.998, ref:Positive) 超 大
#  再 此 铃 声 效 果 -> Positive(confidence:0.999, ref:Positive) 很 不 错
#  所 以 感 觉 音 质 -> Positive(confidence:0.999, ref:Positive) 很 不 错
#  而 且 铃 声 -> Positive(confidence:0.997, ref:Positive) 很 大
#  信 号 -> Positive(confidence:0.998, ref:Positive) 很 强
#  夜 间 拍 摄 效 果 -> Negative(confidence:0.994, ref:Negative) 不 好
#  按 键 的 声 音 -> Positive(confidence:0.559, ref:Positive) 大
#  凭 借 其 大 气 硬 朗 的 外 观 设 计 -> Positive(confidence:0.999, ref:Positive)
#  超 薄 苗 条 的 身 材 -> Positive(confidence:0.979, ref:Positive)
#  强 大 的 商 务 娱 乐 功 能 -> Positive(confidence:0.999, ref:Positive)
#  外 观 -> Positive(confidence:0.998, ref:Positive) 轻 盈
#  做 工 -> Positive(confidence:0.996, ref:Positive) 精 细
#  选 料 -> Positive(confidence:0.998, ref:Positive) 上 乘
#  该 机 采 用 了 一 块 英 寸 万 色 高 分 辨 率 -> Positive(confidence:0.999, ref:Positive) 屏 幕
#  色 彩 -> Positive(confidence:0.998, ref:Positive) 鲜 明 细 腻
#  层 次 感 -> Positive(confidence:0.998, ref:Positive) 不 错
#  显 示 效 果 -> Positive(confidence:0.998, ref:Positive) 十 分 明 显
#  强 大 的 商 务 功 能 -> Positive(confidence:0.998, ref:Positive)
#  强 大 的 娱 乐 休 闲 功 能 -> Positive(confidence:0.999, ref:Positive)
#  本 机 采 用 主 流 的 和 弦 铃 声 -> Positive(confidence:0.998, ref:Positive)
#  使 拍 照 时 手 机 持 握 感 -> Positive(confidence:0.998, ref:Positive) 很 强
#  按 键 手 感 -> Negative(confidence:0.994, ref:Negative) 差
#  按 键 灵 敏 度 -> Negative(confidence:0.995, ref:Negative) 差
#  手 机 的 音 质 中 频 -> Positive(confidence:0.999, ref:Positive) 表 现 还 可 以
#  低 频 和 高 频 部 分 -> Negative(confidence:0.997, ref:Negative) 表 现 就 稍 差
#  电 池 续 航 能 力 -> Negative(confidence:0.996, ref:Negative) 差
#  笔 尖 -> Negative(confidence:0.988, ref:Negative) 太 细
#  笔 尖 和 保 护 贴 -> Negative(confidence:0.996, ref:Negative) 之 间 有 点 涩
#  菜 单 反 应 速 度 -> Negative(confidence:0.996, ref:Negative) 不 如 预 想 的 快
#  拍 摄 效 果 -> Negative(confidence:0.988, ref:Negative) 果 然 是 差
#  彩 屏 -> Negative(confidence:0.995, ref:Negative) 稍 偏 暗 些
#  系 统 的 反 应 速 度 -> Negative(confidence:0.996, ref:Negative) 会 又 慢 一 点
#  手 写 笔 -> Positive(confidence:0.997, ref:Positive) 粗 细 适 中
#  手 感 -> Positive(confidence:0.998, ref:Positive) 不 错
#  但 是 书 写 时 手 感 -> Negative(confidence:0.996, ref:Negative) 既 涩 且 硬
#  操 作 -> Positive(confidence:0.998, ref:Positive) 巨 爽
#  摇 杆 操 作 -> Positive(confidence:0.998, ref:Positive) 灵 活
#  我 发 短 信 的 速 度 -> Positive(confidence:0.999, ref:Positive) 还 是 很 快 的
#  发 短 信 打 字 用 笔 划 速 度 -> Positive(confidence:0.999, ref:Positive) 比 三 星 还 要 快
#  听 筒 音 量 -> Negative(confidence:0.995, ref:Negative) 偏 小
#  菜 单 响 应 速 度 -> Negative(confidence:0.995, ref:Negative) 较 慢
#  信 号 -> Negative(confidence:0.994, ref:Negative) 不 好
#  抢 线 速 度 -> Negative(confidence:0.994, ref:Negative) 慢
#  夜 景 拍 摄 效 果 -> Negative(confidence:0.996, ref:Negative) 较 差
#  红 外 数 据 交 换 速 度 -> Negative(confidence:0.996, ref:Negative) 太 慢
#  声 音 -> Negative(confidence:0.986, ref:Negative) 确 实 小
#  铃 声 -> Negative(confidence:0.996, ref:Negative) 和 通 话 的 声 音 小
#  外 观 -> Positive(confidence:0.997, ref:Positive) 时 尚
#  质 量 -> Positive(confidence:0.988, ref:Positive) 过 硬
#  做 工 -> Positive(confidence:0.998, ref:Positive) 扎 实
#  机 壳 材 质 -> Positive(confidence:0.642, ref:Positive) 硬 朗
#  每 个 细 节 -> Positive(confidence:0.998, ref:Positive) 都 一 丝 不 苟
#  设 计 -> Positive(confidence:0.998, ref:Positive) 出 色
#  功 能 -> Positive(confidence:0.998, ref:Positive) 实 用
#  接 听 语 音 -> Positive(confidence:0.998, ref:Positive) 清 晰 稳 定
#  要 知 道 信 号 -> Positive(confidence:0.805, ref:Positive) 好 可 是 的 招 牌
#  待 机 时 间 -> Positive(confidence:0.998, ref:Positive) 不 错
#  内 存 -> Negative(confidence:0.994, ref:Negative) 太 小
#  下 载 的 铃 声 因 固 定 分 配 的 存 储 空 间 -> Negative(confidence:0.996, ref:Negative) 小 而 不 完 整
#  性 价 比 -> Positive(confidence:0.998, ref:Positive) 比 较 高
#  造 型 -> Positive(confidence:0.998, ref:Positive) 比 较 别 致
#  外 表 的 质 感 -> Positive(confidence:0.999, ref:Positive) 也 比 较 上 乘
#  白 色 的 屏 幕 尺 寸 -> Positive(confidence:0.989, ref:Positive) 大 小 适 中
#  屏 幕 保 护 设 置 -> Positive(confidence:0.999, ref:Positive) 简 单 适 用 美 观
#  声 音 -> Positive(confidence:0.998, ref:Positive) 清 晰
#  还 原 度 -> Positive(confidence:0.998, ref:Positive) 好
#  输 入 法 -> Positive(confidence:0.998, ref:Positive) 简 单 好 用
#  屏 幕 上 面 的 面 积 -> Negative(confidence:0.995, ref:Negative) 过 大
#  数 字 键 盘 设 计 外 形 -> Positive(confidence:0.998, ref:Positive) 别 致
#  但 操 作 性 -> Negative(confidence:0.995, ref:Negative) 较 差
#  手 机 反 应 速 度 -> Negative(confidence:0.995, ref:Negative) 慢
#  通 话 音 量 -> Negative(confidence:0.996, ref:Negative) 不 是 足 够 的 高
#  通 讯 录 容 量 -> Negative(confidence:0.996, ref:Negative) 不 够 大
#  手 机 震 动 -> Negative(confidence:0.995, ref:Negative) 不 够 强
#  就 是 身 材 -> Negative(confidence:0.572, ref:Negative) 要 比 诺 基 亚 憨 厚 的 多
#  机 壳 表 面 -> Positive(confidence:0.999, ref:Positive) 光 滑 细 腻 带 有 金 属 质 感
#  发 现 它 的 信 号 -> Positive(confidence:0.998, ref:Positive) 不 错
#  通 话 -> Positive(confidence:0.998, ref:Positive) 清 晰 明 亮
#  功 能 -> Positive(confidence:0.998, ref:Positive) 也 很 贴 心
#  在 千 元 左 右 的 手 机 中 摩 托 罗 拉 算 是 功 能 -> Positive(confidence:0.999, ref:Positive) 齐 全 的 低 价 位 手 机
#  小 的 可 怜 的 屏 幕 -> Negative(confidence:0.993, ref:Negative)
#  和 旋 铃 声 -> Negative(confidence:0.988, ref:Negative) 假 的 让 人 倒 胃 口
#  其 他 的 按 键 -> Negative(confidence:0.996, ref:Negative) 一 律 为 很 粗 糙 的 那 种
#  但 由 于 的 体 积 -> Negative(confidence:0.958, ref:Positive) 较 小
#  推 开 滑 盖 后 就 呈 现 出 硕 大 的 数 字 键 盘 -> Positive(confidence:0.999, ref:Positive)
#  的 实 际 表 现 -> Positive(confidence:0.857, ref:Negative) 只 能 算 是 中 规 中 矩
#  虽 然 屏 幕 的 细 腻 程 度 -> Negative(confidence:0.994, ref:Negative) 不 高
#  但 是 屏 幕 的 亮 度 -> Positive(confidence:0.999, ref:Positive) 还 是 不 错 的
#  相 信 可 以 在 一 定 程 度 上 祢 补 显 示 效 果 -> Positive(confidence:0.961, ref:Negative) 的 不 足
#  铃 声 穿 透 力 -> Negative(confidence:0.996, ref:Negative) 不 是 很 足 够
#  音 色 -> Positive(confidence:0.998, ref:Positive) 尚 算 清 晰
#  层 次 感 -> Positive(confidence:0.976, ref:Positive) 较 强
#  总 体 来 讲 的 声 音 效 果 -> Positive(confidence:0.994, ref:Negative) 算 是 中 规 中 矩
#  屏 幕 -> Negative(confidence:0.994, ref:Negative) 过 小
#  显 示 效 果 -> Negative(confidence:0.995, ref:Negative) 一 般
#  拍 照 效 果 -> Negative(confidence:0.985, ref:Negative) 不 甚 理 想
#  是 系 列 里 做 工 -> Positive(confidence:0.999, ref:Positive) 最 好 的 手 机 了
#  紧 凑 的 按 键 设 计 -> Positive(confidence:0.997, ref:Positive)
#  做 工 -> Positive(confidence:0.998, ref:Positive) 令 人 满 意
#  手 感 -> Positive(confidence:0.998, ref:Positive) 很 好
#  这 个 体 积 -> Positive(confidence:0.995, ref:Positive) 已 经 是 很 理 想 的 了
#  通 话 效 果 -> Positive(confidence:0.998, ref:Positive) 不 错
#  话 音 -> Positive(confidence:0.998, ref:Positive) 清 晰 饱 满
#  室 内 室 外 通 话 -> Positive(confidence:0.999, ref:Positive) 均 十 分 清 晰
#  色 彩 表 现 力 -> Positive(confidence:0.998, ref:Positive) 极 强
#  金 属 外 壳 -> Positive(confidence:0.998, ref:Positive) 当 然 很 值 得 一 提 啦
#  来 电 防 火 墙 -> Positive(confidence:0.999, ref:Positive) 非 常 好 用
#  听 看 小 电 影 音 质 -> Positive(confidence:0.998, ref:Positive) 音 量 还 可 以 啦
#  机 械 感 -> Negative(confidence:0.964, ref:Positive) 比 较 强
#  天 线 折 叠 -> Positive(confidence:0.996, ref:Positive) 是 个 创 意
#  机 身 可 使 用 内 存 -> Negative(confidence:0.996, ref:Negative) 太 少 了
#  手 写 笔 -> Negative(confidence:0.995, ref:Negative) 太 轻 太 短
#  整 体 外 观 -> Positive(confidence:0.998, ref:Positive) 显 得 比 较 柔 和
#  手 感 -> Positive(confidence:0.998, ref:Positive) 也 相 当 好
#  铃 声 种 类 -> Positive(confidence:0.998, ref:Positive) 丰 富 多 彩
#  音 色 -> Positive(confidence:0.998, ref:Positive) 纯 正 而 丰 富
#  这 个 功 能 -> Positive(confidence:0.999, ref:Positive) 还 是 十 分 的 方 便 实 用 的
#  所 以 整 体 色 彩 -> Negative(confidence:0.995, ref:Positive) 表 现 一 般
#  整 体 亮 度 -> Negative(confidence:0.996, ref:Negative) 稍 显 不 足
#  虽 然 这 两 款 游 戏 的 可 玩 性 -> Positive(confidence:0.998, ref:Positive) 尚 可
#  但 整 体 的 娱 乐 性 -> Negative(confidence:0.995, ref:Negative) 还 是 比 较 单 调 的
#  小 巧 玲 珑 的 机 身 -> Positive(confidence:0.998, ref:Positive)
#  做 工 -> Positive(confidence:0.998, ref:Positive) 出 色
#  缝 隙 -> Positive(confidence:0.995, ref:Positive) 小
#  机 身 -> Positive(confidence:0.998, ref:Positive) 契 合 严 密
#  烤 漆 -> Positive(confidence:0.998, ref:Positive) 处 理 精 致
#  软 件 -> Positive(confidence:0.998, ref:Positive) 人 性 化
#  菜 单 -> Positive(confidence:0.998, ref:Positive) 也 好 看
# inference result saved in: /content/apc_inference.result.json
# Total samples:657
# Labeled samples:649
# Prediction Accuracy:96.45608628659475%
# /usr/local/lib/python3.7/dist-packages/pyabsa/core/apc/prediction/sentiment_classifier.py:181: ResourceWarning: unclosed file <_io.TextIOWrapper name='/content/apc_inference.result.json' mode='w' encoding='utf8'>
#   return self._infer(save_path=save_path if save_result else None, print_result=print_result)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %% [markdown]
# # Train a model (Fast-LCF) for Aspect-based sentiment classification
# ## We dont run a training on Colab as it is too slow

# %%
from pyabsa.functional import Trainer
from pyabsa.functional import APCConfigManager
from pyabsa.functional import ABSADatasetList
from pyabsa.functional import APCModelList

apc_config_english = APCConfigManager.get_apc_config_english()
apc_config_english.model = APCModelList.FAST_LCF_BERT
apc_config_english.num_epoch = 1
apc_config_english.evaluate_begin = 0
apc_config_english.pretrained_bert = 'microsoft/deberta-v3-base'
apc_config_english.similarity_threshold = 1
apc_config_english.max_seq_len = 80
apc_config_english.dropout = 0.5
apc_config_english.seed = 2672
apc_config_english.log_step = 50
apc_config_english.l2reg = 1e-8
apc_config_english.dynamic_truncate = True
apc_config_english.srd_alignment = True

Dataset = ABSADatasetList.Laptop14
sent_classifier = Trainer(config=apc_config_english,
               dataset=Dataset,
               checkpoint_save_mode=0,
               auto_device=True
               ).load_trained_model()

# %% [markdown]
# # Train on your own dataset from a checkpoint

# %%
apc_config_english = APCConfigManager.get_apc_config_english()
apc_config_english.model = APCModelList.FAST_LSA_T
apc_config_english.evaluate_begin = 2
apc_config_english.similarity_threshold = 1
apc_config_english.max_seq_len = 80
apc_config_english.dropout = 0.5
apc_config_english.log_step = 5
apc_config_english.l2reg = 0.0001
apc_config_english.dynamic_truncate = True
apc_config_english.srd_alignment = True

checkpoint_path = APCCheckpointManager.get_checkpoint('english')
SemEval = ABSADatasetList.SemEval

sent_classifier = Trainer(config=apc_config_english,
                          dataset=SemEval,
                          from_checkpoint=checkpoint_path,
                          checkpoint_save_mode=1,
                          auto_device=True
                          ).load_trained_model()

# %% [markdown]
# # We provide GloVe models and BERT-Baseline models, you can use them with some modification

# %% [markdown]
# ## GloVe model training

# %%
from pyabsa import APCTrainer, APCConfigManager, GloVeAPCModelList, ABSADatasetList

# Put glove embedding under current path first if you dont want to download GloVe embedding
apc_config_english = APCConfigManager.get_apc_config_glove()
apc_config_english.model = GloVeAPCModelList.TNet_LF
apc_config_english.num_epoch = 20
apc_config_english.cross_validate_fold = -1  # disable cross_validate, enable in {5, 10}

Dataset = ABSADatasetList.SemEval
sent_classifier = APCTrainer(config=apc_config_english,  # set config=None will use the apc_config as well
                dataset=Dataset,  # train set and test set will be automatically detected
                checkpoint_save_mode=1,  # set model_path_to_save=None to avoid save model
                auto_device=True  # automatic choose CUDA or CPU
                ).train()

# %% [markdown]
# ## BERT baseline model training

# %%
from pyabsa import APCTrainer, APCConfigManager, BERTBaselineAPCModelList, ABSADatasetList

apc_config_english = APCConfigManager.get_apc_config_bert_baseline()
apc_config_english.model = BERTBaselineAPCModelList.ASGCN_BERT
apc_config_english.num_epoch = 10
apc_config_english.evaluate_begin = 2
apc_config_english.max_seq_len = 100
apc_config_english.dropout = 0.5
apc_config_english.log_step = 5
apc_config_english.l2reg = 0.0005
apc_config_english.seed = 1
apc_config_english.use_syntax_based_SRD = True
apc_config_english.similarity_threshold = 1
apc_config_english.cross_validate_fold = -1  # disable cross_validate

laptop14 = ABSADatasetList.Laptop14
sent_classifier = APCTrainer(config=apc_config_english,
                 dataset=laptop14,  # train set and test set will be automatically detected
                 checkpoint_save_mode=1,  # None to avoid save model
                 auto_device=True  # automatic choose CUDA or CPU
                 ).train()

# %% [markdown]
# # Deplyment Example
